# %% [markdown]
# # Precomputation

# %% [markdown]
# # Cell 1: Imports

# %%
import os
import random
import glob
import datetime
import time
from PIL import Image
import numpy as np
import math
# import subprocess # 通常在 notebook 中不直接运行外部脚本
# import shlex # 同上

import torch
import torch.nn as nn
# import torch.nn.functional as F # 如果GigaPath模型内部需要，否则可能不需要直接用
# import torch.optim as optim # 进行预计算时不需要优化器
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast

import torchvision.transforms as transforms
# from torchvision.utils import make_grid, save_image # 如果不进行可视化，则不需要

import timm # GigaPath 需要的库

try:
    from tqdm.notebook import tqdm as notebook_tqdm
    IS_NOTEBOOK = True
    print("侦测到 Notebook 环境。")
except ImportError:
    from tqdm.auto import tqdm as notebook_tqdm # Fallback for non-notebook
    IS_NOTEBOOK = False
    print("未完全侦测到 Notebook 环境。使用标准 tqdm。")
# Out:
# 侦测到 Notebook 环境。

# %% [markdown]
# ## Validate the graph data

# %%
import torch
import os
import glob
import platform

# --- 前置条件 ---
# 请确保你的 TrainingConfig 类已定义，并且名为 `config` 的实例已创建。
# 如果还没有，请将 TrainingConfig 类的定义粘贴到此单元格的顶部，并实例化它，例如：
#
class TrainingConfig:
    # --- Data Paths ---
    LATENT_DIR = "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16"
    GRAPH_DATA_DIR = "/cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6"
    # ... (你的其他配置项) ...
#
config = TrainingConfig()  # 确保 config 实例存在
# # 确保 config 实例存在
if 'config' not in locals() or not isinstance(config, TrainingConfig):
    print("警告: 'config' 未定义或类型不正确。请先定义并实例化 TrainingConfig 类。")
    # 为防止脚本出错，这里可以创建一个虚拟的 config，但最好是用户提供真实的
    class DummyConfig:
        GRAPH_DATA_DIR = "YOUR_GRAPH_DATA_DIR_HERE" # 用户需要替换
        LATENT_DIR = "YOUR_LATENT_DIR_HERE"       # 用户需要替换
    if 'config' not in locals(): config = DummyConfig() # 仅为示例，实际应由用户提供 TrainingConfig
#
# --- 用户配置检查部分 ---
# 1. 指定要检查的图文件的索引 (从列出的文件中选择)
#    如果你想覆盖自动选择，请直接设置 SPECIFIC_GRAPH_FILE_PATH_OVERRIDE
FILE_INDEX_TO_CHECK = 0  # 默认检查第0个 (第一个) 文件
SPECIFIC_GRAPH_FILE_PATH_OVERRIDE = None # 若要手动指定完整路径，请取消注释并修改，例如: "/path/to/your/specific_graph.pt"
# 2. 是否简略显示每个路径的检查结果 (只显示统计和错误)
CONCISE_OUTPUT_PER_PATH = False # 设置为 True 以获得更简洁的逐路径输出
# --- 用户配置结束 ---

# --- 主要检查逻辑 ---
print(f"--- 开始检查图文件中的 'latent_paths' (单单元格版本) ---")
print(f"操作系统: {platform.system()} {platform.release()}, 当前工作目录: {os.getcwd()}")

selected_graph_file_to_check = None
graph_files_found = []

try:
    if 'config' not in locals():
        raise NameError("错误: 'config' 对象未定义。请确保 TrainingConfig 类已定义并已创建其实例 'config'。")

    graph_data_directory = config.GRAPH_DATA_DIR
    expected_latent_base_dir = config.LATENT_DIR
    print(f"图数据目录 (来自config): {graph_data_directory}")
    print(f"Latent基准目录 (来自config): {expected_latent_base_dir}")

    if SPECIFIC_GRAPH_FILE_PATH_OVERRIDE:
        selected_graph_file_to_check = SPECIFIC_GRAPH_FILE_PATH_OVERRIDE
        if not os.path.exists(selected_graph_file_to_check):
             print(f"⚠️ 警告: 手动指定的图文件 '{selected_graph_file_to_check}' 不存在。")
    elif not os.path.isdir(graph_data_directory):
        print(f"❌ 错误: 图数据目录 '{graph_data_directory}' 不存在或不是一个目录。")
    else:
        search_pattern = os.path.join(graph_data_directory, "*.pt") # 你可以修改为更精确的模式如 "*_graph.pt"
        graph_files_found = sorted(glob.glob(search_pattern))
        if graph_files_found:
            print(f"\n在 '{graph_data_directory}' 中找到以下图文件 (模式: '{search_pattern}'):")
            for i, f_path in enumerate(graph_files_found):
                print(f"  [{i}] {os.path.basename(f_path)}")
            
            if 0 <= FILE_INDEX_TO_CHECK < len(graph_files_found):
                selected_graph_file_to_check = graph_files_found[FILE_INDEX_TO_CHECK]
                print(f"\n✅ 自动选择索引为 {FILE_INDEX_TO_CHECK} 的文件进行检查: '{os.path.basename(selected_graph_file_to_check)}'")
                print(f"   完整路径: {selected_graph_file_to_check}")
                print(f"   (提示: 可修改本单元格顶部的 FILE_INDEX_TO_CHECK 或 SPECIFIC_GRAPH_FILE_PATH_OVERRIDE 来选择其他文件)")
            else:
                print(f"❌ 错误: 指定的 FILE_INDEX_TO_CHECK ({FILE_INDEX_TO_CHECK}) 超出范围 (0-{len(graph_files_found)-1})。")
        else:
            print(f"  ⚠️ 在 '{graph_data_directory}' 中未找到匹配的图文件 (模式: '{search_pattern}')。")

    if not selected_graph_file_to_check or not os.path.exists(selected_graph_file_to_check):
        print(f"\n❌ 未能确定有效的图文件进行检查。脚本终止。")
    else:
        print("-" * 50)
        print(f"🚀 开始详细检查文件: {selected_graph_file_to_check}")
        graph_data = torch.load(selected_graph_file_to_check, map_location='cpu')
        print(f"✅ 成功加载图数据。")

        if not hasattr(graph_data, 'latent_paths'):
            print("\n❌ 错误: 图数据中未找到 'latent_paths' 属性。")
            keys_available = list(graph_data.keys) if hasattr(graph_data, 'keys') and callable(graph_data.keys) else [d for d in dir(graph_data) if not d.startswith('_')]
            print(f"  图对象中可用的keys/属性 (部分): {keys_available[:15]}")
        else:
            latent_paths_list = graph_data.latent_paths
            print(f"\n➡️ 属性 'latent_paths' 存在。")

            if latent_paths_list is None:
                print("  ⚠️ 值为 None。")
            elif isinstance(latent_paths_list, (list, tuple)) and len(latent_paths_list) > 0:
                num_paths = len(latent_paths_list)
                num_nodes = getattr(graph_data, 'num_nodes', 'N/A (未找到属性)')
                print(f"  包含 {num_paths} 个路径条目。图中节点数 (num_nodes): {num_nodes}.")
                if isinstance(num_nodes, int) and num_paths != num_nodes:
                    print(f"  ⚠️ 警告: 路径数 ({num_paths}) 与节点数 ({num_nodes}) 不匹配!")

                found_count, not_found_count, none_path_count = 0, 0, 0
                
                # 为了简洁，只展示前5条和后5条的详细信息（如果路径总数较多）
                indices_to_show_detail = set(list(range(min(num_paths, 5))) + list(range(max(0, num_paths - 5), num_paths)))

                for i, path_in_graph in enumerate(latent_paths_list):
                    is_detailed_view = (i in indices_to_show_detail) or (not CONCISE_OUTPUT_PER_PATH)

                    if path_in_graph is None:
                        none_path_count += 1
                        if is_detailed_view: print(f"  路径 {i+1}/{num_paths}: None")
                        continue # None 路径直接跳过后续文件检查，计入not_found

                    path_str = str(path_in_graph)
                    exists_directly = os.path.exists(path_str)
                    exists_with_base = False
                    
                    if not exists_directly and expected_latent_base_dir and not os.path.isabs(path_str):
                        resolved_path_with_base = os.path.join(os.path.normpath(expected_latent_base_dir), os.path.normpath(path_str))
                        exists_with_base = os.path.exists(resolved_path_with_base)
                    
                    if exists_directly or exists_with_base:
                        found_count += 1
                        if is_detailed_view and not CONCISE_OUTPUT_PER_PATH:
                             status_detail = f"(绝对路径: '{os.path.abspath(path_str)}')" if exists_directly else f"(基于基准目录 '{expected_latent_base_dir}' 解析为 '{os.path.abspath(resolved_path_with_base)}')"
                             print(f"  路径 {i+1}/{num_paths}: \"{path_str}\" ✅ 找到 {status_detail}")
                    else:
                        not_found_count += 1
                        if is_detailed_view:
                             print(f"  路径 {i+1}/{num_paths}: \"{path_str}\" ❌ 未找到")
                             if not CONCISE_OUTPUT_PER_PATH :
                                 if os.path.isabs(path_str):
                                     print(f"    提示: 这是一个绝对路径但不存在。")
                                 else:
                                     print(f"    提示: 这是一个相对路径。当前工作目录 '{os.getcwd()}'。")
                                     if expected_latent_base_dir: print(f"    尝试的基准目录拼接路径 '{resolved_path_with_base if 'resolved_path_with_base' in locals() else 'N/A'}' (也不存在)。")
                                     else: print(f"    未提供基准目录，若为相对路径请检查。")

                # 实际未找到文件的是 not_found_count (不含None的初始计数) + none_path_count (None也算未找到)
                actual_not_found_files = not_found_count + none_path_count

                print("-" * 30)
                print(f"  📊 路径检查统计:")
                print(f"    总路径条目数: {num_paths}")
                print(f"    值为 None 的路径数: {none_path_count}")
                print(f"    有效并找到文件的路径数: {found_count}")
                print(f"    未找到对应文件的路径数 (包含值为None的路径): {actual_not_found_files}")
                if (found_count + actual_not_found_files) != num_paths:
                     print(f"    ⚠️ 统计总和 ({found_count + actual_not_found_files}) 与总路径数 ({num_paths}) 不符，请检查逻辑。")


            elif isinstance(latent_paths_list, (list, tuple)) and len(latent_paths_list) == 0:
                print("  ⚠️ 'latent_paths' 是一个空列表/元组。")
            else:
                print(f"  ❓ 'latent_paths' 类型为 {type(latent_paths_list)}，非预期格式。内容预览: {str(latent_paths_list)[:200]}")

except NameError as ne: # 特别捕捉 config 未定义的错误
    print(ne)
    print("请确保在此单元格顶部或之前的单元格中正确定义 TrainingConfig 类并创建其实例 'config'。")
except FileNotFoundError as fnfe:
    print(f"❌ 文件未找到错误: {fnfe}")
except Exception as e:
    print(f"❌ 处理过程中发生错误: {e}")
    import traceback
    traceback.print_exc()

print(f"\n--- 检查脚本结束 ---")
# Out:
# --- 开始检查图文件中的 'latent_paths' (单单元格版本) ---
# 操作系统: Linux 3.10.0-1160.el7.x86_64, 当前工作目录: /public/home/jijh
# 图数据目录 (来自config): /cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6
# Latent基准目录 (来自config): /cwStorage/nodecw_group/jijh/hest_output_latents_bf16
#
# 在 '/cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6' 中找到以下图文件 (模式: '/cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6/*.pt'):
#   [0] MEND123_graph.pt
#   [1] MEND124_graph.pt
#   [2] MEND129_graph.pt
#   [3] MEND130_graph.pt
#   [4] MEND131_graph.pt
#   [5] MEND42_graph.pt
#   [6] MEND43_graph.pt
#   [7] MEND44_graph.pt
#   [8] MEND46_graph.pt
#   [9] MEND50_graph.pt
#   [10] MEND53_graph.pt
#   [11] MEND55_graph.pt
#   [12] MEND63_graph.pt
#   [13] MEND64_graph.pt
#   [14] MEND65_graph.pt
#   [15] MEND66_graph.pt
#   [16] MEND67_graph.pt
#   [17] MEND68_graph.pt
#   [18] MEND71_graph.pt
#   [19] MEND72_graph.pt
#   [20] MEND73_graph.pt
#   [21] MEND74_graph.pt
#   [22] MEND75_graph.pt
#   [23] MEND76_graph.pt
#   [24] MEND77_graph.pt
#   [25] MEND78_graph.pt
#   [26] MISC10_graph.pt
#   [27] MISC11_graph.pt
#   [28] MISC12_graph.pt
#   [29] MISC1_graph.pt
#   [30] MISC2_graph.pt
#   [31] MISC3_graph.pt
#   [32] MISC4_graph.pt
#   [33] MISC5_graph.pt
#   [34] MISC6_graph.pt
#   [35] MISC7_graph.pt
#   [36] MISC8_graph.pt
#   [37] MISC9_graph.pt
#   [38] NCBI336_graph.pt
#   [39] NCBI337_graph.pt
#   [40] NCBI338_graph.pt
#   [41] NCBI339_graph.pt
#   [42] NCBI340_graph.pt
#   [43] NCBI341_graph.pt
#   [44] NCBI342_graph.pt
#   [45] NCBI343_graph.pt
#   [46] NCBI344_graph.pt
#   [47] NCBI345_graph.pt
#   [48] NCBI346_graph.pt
#   [49] NCBI347_graph.pt
#   [50] NCBI348_graph.pt
#   [51] NCBI349_graph.pt
#   [52] NCBI350_graph.pt
#   [53] NCBI351_graph.pt
#   [54] NCBI352_graph.pt
#   [55] NCBI353_graph.pt
#   [56] NCBI354_graph.pt
#   [57] NCBI355_graph.pt
#   [58] NCBI356_graph.pt
#   [59] NCBI357_graph.pt
#   [60] NCBI358_graph.pt
#   [61] NCBI359_graph.pt
#   [62] NCBI360_graph.pt
#   [63] NCBI361_graph.pt
#   [64] NCBI362_graph.pt
#   [65] NCBI363_graph.pt
#   [66] NCBI364_graph.pt
#   [67] NCBI365_graph.pt
#   [68] NCBI366_graph.pt
#   [69] NCBI367_graph.pt
#   [70] NCBI368_graph.pt
#   [71] NCBI369_graph.pt
#   [72] NCBI370_graph.pt
#   [73] NCBI371_graph.pt
#   [74] NCBI372_graph.pt
#   [75] NCBI373_graph.pt
#   [76] NCBI374_graph.pt
#   [77] NCBI375_graph.pt
#   [78] NCBI376_graph.pt
#   [79] NCBI377_graph.pt
#   [80] NCBI378_graph.pt
#   [81] NCBI379_graph.pt
#   [82] NCBI380_graph.pt
#   [83] NCBI381_graph.pt
#   [84] NCBI382_graph.pt
#   [85] NCBI383_graph.pt
#   [86] NCBI384_graph.pt
#   [87] NCBI385_graph.pt
#   [88] NCBI386_graph.pt
#   [89] NCBI387_graph.pt
#   [90] NCBI388_graph.pt
#   [91] NCBI389_graph.pt
#   [92] NCBI390_graph.pt
#   [93] NCBI391_graph.pt
#   [94] NCBI392_graph.pt
#   [95] NCBI393_graph.pt
#   [96] NCBI394_graph.pt
#   [97] NCBI395_graph.pt
#   [98] NCBI396_graph.pt
#   [99] NCBI397_graph.pt
#   [100] NCBI398_graph.pt
#   [101] NCBI399_graph.pt
#   [102] NCBI400_graph.pt
#   [103] NCBI401_graph.pt
#   [104] NCBI402_graph.pt
#   [105] NCBI403_graph.pt
#   [106] NCBI404_graph.pt
#   [107] NCBI405_graph.pt
#   [108] NCBI406_graph.pt
#   [109] NCBI407_graph.pt
#   [110] NCBI408_graph.pt
#   [111] NCBI409_graph.pt
#   [112] NCBI410_graph.pt
#   [113] NCBI527_graph.pt
#   [114] NCBI528_graph.pt
#   [115] NCBI529_graph.pt
#   [116] NCBI530_graph.pt
#   [117] NCBI531_graph.pt
#   [118] NCBI532_graph.pt
#   [119] NCBI533_graph.pt
#   [120] NCBI628_graph.pt
#   [121] NCBI629_graph.pt
#   [122] NCBI630_graph.pt
#   [123] NCBI631_graph.pt
#   [124] NCBI632_graph.pt
#   [125] NCBI633_graph.pt
#   [126] NCBI634_graph.pt
#   [127] NCBI635_graph.pt
#   [128] NCBI636_graph.pt
#   [129] NCBI637_graph.pt
#   [130] NCBI638_graph.pt
#   [131] NCBI639_graph.pt
#   [132] NCBI640_graph.pt
#   [133] NCBI641_graph.pt
#   [134] NCBI653_graph.pt
#   [135] NCBI654_graph.pt
#   [136] NCBI655_graph.pt
#   [137] NCBI656_graph.pt
#   [138] NCBI657_graph.pt
#   [139] NCBI658_graph.pt
#   [140] NCBI659_graph.pt
#   [141] NCBI660_graph.pt
#   [142] NCBI661_graph.pt
#   [143] NCBI662_graph.pt
#   [144] NCBI663_graph.pt
#   [145] NCBI664_graph.pt
#   [146] NCBI665_graph.pt
#   [147] NCBI666_graph.pt
#   [148] NCBI667_graph.pt
#   [149] NCBI668_graph.pt
#   [150] NCBI669_graph.pt
#   [151] NCBI670_graph.pt
#   [152] NCBI671_graph.pt
#   [153] NCBI715_graph.pt
#   [154] NCBI716_graph.pt
#   [155] NCBI717_graph.pt
#   [156] NCBI718_graph.pt
#   [157] NCBI719_graph.pt
#   [158] NCBI720_graph.pt
#   [159] NCBI799_graph.pt
#   [160] NCBI800_graph.pt
#   [161] NCBI801_graph.pt
#   [162] NCBI802_graph.pt
#   [163] NCBI806_graph.pt
#   [164] NCBI807_graph.pt
#   [165] NCBI808_graph.pt
#   [166] NCBI809_graph.pt
#   [167] SPA10_graph.pt
#   [168] SPA12_graph.pt
#   [169] SPA13_graph.pt
#   [170] SPA14_graph.pt
#   [171] SPA15_graph.pt
#   [172] SPA4_graph.pt
#   [173] SPA5_graph.pt
#   [174] SPA6_graph.pt
#   [175] SPA7_graph.pt
#   [176] SPA8_graph.pt
#   [177] SPA9_graph.pt
#   [178] TENX131_graph.pt
#   [179] TENX138_graph.pt
#   [180] TENX159_graph.pt
#   [181] TENX18_graph.pt
#   [182] TENX19_graph.pt
#   [183] TENX27_graph.pt
#   [184] TENX30_graph.pt
#   [185] TENX31_graph.pt
#   [186] TENX43_graph.pt
#   [187] TENX52_graph.pt
#   [188] TENX54_graph.pt
#   [189] TENX55_graph.pt
#   [190] TENX56_graph.pt
#   [191] TENX58_graph.pt
#   [192] TENX60_graph.pt
#   [193] TENX61_graph.pt
#   [194] TENX67_graph.pt
#   [195] TENX69_graph.pt
#   [196] TENX73_graph.pt
#   [197] TENX77_graph.pt
#   [198] TENX78_graph.pt
#   [199] TENX79_graph.pt
#   [200] TENX80_graph.pt
#   [201] TENX83_graph.pt
#   [202] TENX84_graph.pt
#   [203] TENX85_graph.pt
#   [204] TENX86_graph.pt
#   [205] TENX87_graph.pt
#   [206] TENX88_graph.pt
#   [207] ZEN60_graph.pt
#   [208] ZEN61_graph.pt
#
# ✅ 自动选择索引为 0 的文件进行检查: 'MEND123_graph.pt'
#    完整路径: /cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6/MEND123_graph.pt
#    (提示: 可修改本单元格顶部的 FILE_INDEX_TO_CHECK 或 SPECIFIC_GRAPH_FILE_PATH_OVERRIDE 来选择其他文件)
# --------------------------------------------------
# 🚀 开始详细检查文件: /cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6/MEND123_graph.pt
# /tmp/ipykernel_27448/3791193029.py:80: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   graph_data = torch.load(selected_graph_file_to_check, map_location='cpu')
# ✅ 成功加载图数据。
#
# ➡️ 属性 'latent_paths' 存在。
#   包含 1490 个路径条目。图中节点数 (num_nodes): 1490.
#   路径 1/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20022_24778.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20022_24778.pt')
#   路径 2/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_30299.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_30299.pt')
#   路径 3/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_18095.pt')
#   路径 4/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_20420.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_20420.pt')
#   路径 5/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_16642.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_16642.pt')
#   路径 6/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_38144.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_38144.pt')
#   路径 7/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_18966.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_18966.pt')
#   路径 8/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_30589.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_30589.pt')
#   路径 9/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22551_30880.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22551_30880.pt')
#   路径 10/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_10922_29428.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_10922_29428.pt')
#   路径 11/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_31461.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_31461.pt')
#   路径 12/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_25649.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_25649.pt')
#   路径 13/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_35529.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_35529.pt')
#   路径 14/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_36982.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_36982.pt')
#   路径 15/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_31751.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_31751.pt')
#   路径 16/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22551_33204.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22551_33204.pt')
#   路径 17/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_27974.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_27974.pt')
#   路径 18/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_19548.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_19548.pt')
#   路径 19/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_28555.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_28555.pt')
#   路径 20/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25585_37272.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25585_37272.pt')
#   路径 21/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_17495_27974.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_17495_27974.pt')
#   路径 22/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_10922_20710.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_10922_20710.pt')
#   路径 23/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34685_29717.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34685_29717.pt')
#   路径 24/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27100_16642.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27100_16642.pt')
#   路径 25/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25079_31170.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25079_31170.pt')
#   路径 26/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_18095.pt')
#   路径 27/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_23035.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_23035.pt')
#   路径 28/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_23615.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_23615.pt')
#   路径 29/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_24778.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_24778.pt')
#   路径 30/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_22163.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_22163.pt')
#   路径 31/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21033_16061.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21033_16061.pt')
#   路径 32/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30640_26230.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30640_26230.pt')
#   路径 33/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_16932.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_16932.pt')
#   路径 34/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12944_18386.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12944_18386.pt')
#   路径 35/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_31461.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_31461.pt')
#   路径 36/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_19838.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_19838.pt')
#   路径 37/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_22163.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_22163.pt')
#   路径 38/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_30008.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_30008.pt')
#   路径 39/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16988_14899.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16988_14899.pt')
#   路径 40/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25078_23034.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25078_23034.pt')
#   路径 41/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_18385.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_18385.pt')
#   路径 42/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_18095.pt')
#   路径 43/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_25650.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_25650.pt')
#   路径 44/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18505_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18505_18095.pt')
#   路径 45/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_30589.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_30589.pt')
#   路径 46/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_32333.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_32333.pt')
#   路径 47/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24068_32333.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24068_32333.pt')
#   路径 48/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_33786.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_33786.pt')
#   路径 49/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_20710.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_20710.pt')
#   路径 50/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_22744.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_22744.pt')
#   路径 51/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30640_29136.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30640_29136.pt')
#   路径 52/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_25940.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_25940.pt')
#   路径 53/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31145_23034.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31145_23034.pt')
#   路径 54/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_31170.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_31170.pt')
#   路径 55/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23057_37563.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23057_37563.pt')
#   路径 56/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_23906.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_23906.pt')
#   路径 57/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33674_34947.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33674_34947.pt')
#   路径 58/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_21291.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_21291.pt')
#   路径 59/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_33785.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_33785.pt')
#   路径 60/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_24487.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_24487.pt')
#   路径 61/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20023_27684.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20023_27684.pt')
#   路径 62/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_33204.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_33204.pt')
#   路径 63/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_36202_30589.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_36202_30589.pt')
#   路径 64/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_28846.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_28846.pt')
#   路径 65/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_23906.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_23906.pt')
#   路径 66/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_36707_24487.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_36707_24487.pt')
#   路径 67/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14967_26522.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14967_26522.pt')
#   路径 68/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_23325.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_23325.pt')
#   路径 69/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_29427.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_29427.pt')
#   路径 70/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_19548.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_19548.pt')
#   路径 71/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30135_32332.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30135_32332.pt')
#   路径 72/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_35529.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_35529.pt')
#   路径 73/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_27102.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_27102.pt')
#   路径 74/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_24778.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_24778.pt')
#   路径 75/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_23325.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_23325.pt')
#   路径 76/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_29137.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_29137.pt')
#   路径 77/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_18676.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_18676.pt')
#   路径 78/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_29717.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_29717.pt')
#   路径 79/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_26812.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_26812.pt')
#   路径 80/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21034_32333.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21034_32333.pt')
#   路径 81/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31146_27102.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31146_27102.pt')
#   路径 82/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26089_17223.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26089_17223.pt')
#   路径 83/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_18676.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_18676.pt')
#   路径 84/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_20710.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_20710.pt')
#   路径 85/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_11933_18967.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_11933_18967.pt')
#   路径 86/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_18967.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_18967.pt')
#   路径 87/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_24196.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_24196.pt')
#   路径 88/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_25069.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_25069.pt')
#   路径 89/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_34367.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_34367.pt')
#   路径 90/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24572_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24572_18095.pt')
#   路径 91/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34685_30298.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34685_30298.pt')
#   路径 92/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_29427.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_29427.pt')
#   路径 93/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_15189.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_15189.pt')
#   路径 94/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_25940.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_25940.pt')
#   路径 95/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_21001.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_21001.pt')
#   路径 96/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22551_36691.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22551_36691.pt')
#   路径 97/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_11427_22744.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_11427_22744.pt')
#   路径 98/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_19839.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_19839.pt')
#   路径 99/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_25649.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_25649.pt')
#   路径 100/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_19257.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_19257.pt')
#   路径 101/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_30589.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_30589.pt')
#   路径 102/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_24488.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_24488.pt')
#   路径 103/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_32042.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_32042.pt')
#   路径 104/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_33785.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_33785.pt')
#   路径 105/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_16642.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_16642.pt')
#   路径 106/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_24488.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_24488.pt')
#   路径 107/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_17514.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_17514.pt')
#   路径 108/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_32042.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_32042.pt')
#   路径 109/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_24197.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_24197.pt')
#   路径 110/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_18967.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_18967.pt')
#   路径 111/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_37854.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_37854.pt')
#   路径 112/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_27103.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_27103.pt')
#   路径 113/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28617_22163.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28617_22163.pt')
#   路径 114/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33673_22743.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33673_22743.pt')
#   路径 115/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35696_25068.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35696_25068.pt')
#   路径 116/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_28264.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_28264.pt')
#   路径 117/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20023_28846.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20023_28846.pt')
#   路径 118/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30135_31170.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30135_31170.pt')
#   路径 119/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_17804.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_17804.pt')
#   路径 120/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27607_29136.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27607_29136.pt')
#   路径 121/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26596_36691.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26596_36691.pt')
#   路径 122/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_27393.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_27393.pt')
#   路径 123/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25078_25359.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25078_25359.pt')
#   路径 124/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_21872.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_21872.pt')
#   路径 125/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_34366.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_34366.pt')
#   路径 126/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_25940.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_25940.pt')
#   路径 127/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18506_25069.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18506_25069.pt')
#   路径 128/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23561_13446.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23561_13446.pt')
#   路径 129/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_25940.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_25940.pt')
#   路径 130/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_27393.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_27393.pt')
#   路径 131/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_36707_26230.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_36707_26230.pt')
#   路径 132/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29629_29717.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29629_29717.pt')
#   路径 133/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_15480.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_15480.pt')
#   路径 134/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_22163.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_22163.pt')
#   路径 135/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_23325.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_23325.pt')
#   路径 136/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_32042.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_32042.pt')
#   路径 137/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_21582.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21539_21582.pt')
#   路径 138/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_30008.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_30008.pt')
#   路径 139/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14966_23035.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14966_23035.pt')
#   路径 140/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35696_30879.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35696_30879.pt')
#   路径 141/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18505_15770.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18505_15770.pt')
#   路径 142/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_23616.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_23616.pt')
#   路径 143/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12944_24197.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12944_24197.pt')
#   路径 144/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_25359.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_25359.pt')
#   路径 145/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_19257.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_19257.pt')
#   路径 146/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_32333.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_32333.pt')
#   路径 147/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_13446.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_13446.pt')
#   路径 148/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_34076.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_34076.pt')
#   路径 149/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29629_34948.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29629_34948.pt')
#   路径 150/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_31170.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_31170.pt')
#   路径 151/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_30880.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_30880.pt')
#   路径 152/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_25359.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_25359.pt')
#   路径 153/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_23907.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_23907.pt')
#   路径 154/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_17514.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_17514.pt')
#   路径 155/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33673_23906.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33673_23906.pt')
#   路径 156/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_28846.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_28846.pt')
#   路径 157/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34179_33495.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34179_33495.pt')
#   路径 158/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21034_24778.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21034_24778.pt')
#   路径 159/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_22163.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_22163.pt')
#   路径 160/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_21000.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_21000.pt')
#   路径 161/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_15189.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_15189.pt')
#   路径 162/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34684_21581.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34684_21581.pt')
#   路径 163/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_16351.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_16351.pt')
#   路径 164/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21034_30008.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21034_30008.pt')
#   路径 165/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_23325.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_23325.pt')
#   路径 166/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_16933.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_16933.pt')
#   路径 167/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13449_18676.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13449_18676.pt')
#   路径 168/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_25068.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_25068.pt')
#   路径 169/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_17494_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_17494_18095.pt')
#   路径 170/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_36982.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_36982.pt')
#   路径 171/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35190_31170.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35190_31170.pt')
#   路径 172/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_20129.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_20129.pt')
#   路径 173/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30640_27393.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30640_27393.pt')
#   路径 174/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12439_23907.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12439_23907.pt')
#   路径 175/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_13736.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_13736.pt')
#   路径 176/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_38434.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_38434.pt')
#   路径 177/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34684_21000.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_34684_21000.pt')
#   路径 178/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_20129.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_20129.pt')
#   路径 179/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_16642.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_29123_16642.pt')
#   路径 180/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_33204.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32663_33204.pt')
#   路径 181/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_21582.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_21582.pt')
#   路径 182/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_16642.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_16642.pt')
#   路径 183/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_17805.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_17805.pt')
#   路径 184/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_31170.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_31170.pt')
#   路径 185/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_23034.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_23034.pt')
#   路径 186/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_22163.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_22163.pt')
#   路径 187/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12944_23616.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12944_23616.pt')
#   路径 188/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_22743.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_22743.pt')
#   路径 189/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_37853.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_37853.pt')
#   路径 190/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_14899.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_14899.pt')
#   路径 191/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_24487.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_24487.pt')
#   路径 192/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_22744.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_22744.pt')
# ...
#   路径 1418/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_29136.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_29136.pt')
#   路径 1419/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_17804.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_17804.pt')
#   路径 1420/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21540_33205.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_21540_33205.pt')
#   路径 1421/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_19838.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_19838.pt')
#   路径 1422/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22044_13736.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22044_13736.pt')
#   路径 1423/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_21291.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_21291.pt')
#   路径 1424/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_27684.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15978_27684.pt')
#   路径 1425/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_30008.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_30008.pt')
#   路径 1426/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26596_33204.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26596_33204.pt')
#   路径 1427/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_24778.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_24778.pt')
#   路径 1428/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_27974.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_27974.pt')
#   路径 1429/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_21000.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_21000.pt')
#   路径 1430/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_24488.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13450_24488.pt')
#   路径 1431/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_19547.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_19547.pt')
#   路径 1432/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_31461.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_31461.pt')
#   路径 1433/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_26231.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_26231.pt')
#   路径 1434/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26596_34367.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26596_34367.pt')
#   路径 1435/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12438_22163.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12438_22163.pt')
#   路径 1436/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_23325.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32662_23325.pt')
#   路径 1437/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14966_17223.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14966_17223.pt')
#   路径 1438/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_16933.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_16933.pt')
#   路径 1439/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_38725.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_38725.pt')
#   路径 1440/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20023_29427.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20023_29427.pt')
#   路径 1441/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_14608.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22550_14608.pt')
#   路径 1442/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_17804.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19011_17804.pt')
#   路径 1443/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_17494_20420.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_17494_20420.pt')
#   路径 1444/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_18676.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_18676.pt')
#   路径 1445/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_37272.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_37272.pt')
#   路径 1446/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27100_17804.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27100_17804.pt')
#   路径 1447/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18506_29137.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18506_29137.pt')
#   路径 1448/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28113_38144.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28113_38144.pt')
#   路径 1449/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_32333.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_32333.pt')
#   路径 1450/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_26521.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_30134_26521.pt')
#   路径 1451/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_16642.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_16642.pt')
#   路径 1452/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_21291.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_21291.pt')
#   路径 1453/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_24487.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_24487.pt')
#   路径 1454/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_27683.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_33168_27683.pt')
#   路径 1455/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28113_38725.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28113_38725.pt')
#   路径 1456/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_18676.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_18676.pt')
#   路径 1457/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_20710.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_20710.pt')
#   路径 1458/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_21581.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_31651_21581.pt')
#   路径 1459/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14461_18095.pt')
#   路径 1460/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24068_33495.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24068_33495.pt')
#   路径 1461/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_16352.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_16352.pt')
#   路径 1462/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_21872.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_32157_21872.pt')
#   路径 1463/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_21291.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18000_21291.pt')
#   路径 1464/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_20420.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_20420.pt')
#   路径 1465/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_30008.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22045_30008.pt')
#   路径 1466/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14967_24778.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_14967_24778.pt')
#   路径 1467/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_18386.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_13955_18386.pt')
#   路径 1468/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_17223.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_17223.pt')
#   路径 1469/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_19548.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24067_19548.pt')
#   路径 1470/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_26231.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26595_26231.pt')
#   路径 1471/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_26231.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_15472_26231.pt')
#   路径 1472/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35190_21291.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_35190_21291.pt')
#   路径 1473/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_19838.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_20528_19838.pt')
#   路径 1474/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12438_18095.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_12438_18095.pt')
#   路径 1475/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_25359.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23056_25359.pt')
#   路径 1476/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_32914.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16989_32914.pt')
#   路径 1477/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_30298.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28618_30298.pt')
#   路径 1478/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_18676.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_16483_18676.pt')
#   路径 1479/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_27102.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_27102.pt')
#   路径 1480/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26089_18385.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26089_18385.pt')
#   路径 1481/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_23325.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27606_23325.pt')
#   路径 1482/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_14608.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_25584_14608.pt')
#   路径 1483/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_24197.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_26090_24197.pt')
#   路径 1484/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_27974.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_24573_27974.pt')
#   路径 1485/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_24778.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_28112_24778.pt')
#   路径 1486/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18506_30299.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_18506_30299.pt')
#   路径 1487/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_29137.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_19517_29137.pt')
#   路径 1488/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22044_13155.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_22044_13155.pt')
#   路径 1489/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_26812.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_23562_26812.pt')
#   路径 1490/1490: "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_29427.pt" ✅ 找到 (绝对路径: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123_tiles/MEND123_27101_29427.pt')
# ------------------------------
#   📊 路径检查统计:
#     总路径条目数: 1490
#     值为 None 的路径数: 0
#     有效并找到文件的路径数: 1490
#     未找到对应文件的路径数 (包含值为None的路径): 0
#
# --- 检查脚本结束 ---

# %% [markdown]
# # Cell 2: Configuration

# %%
class TrainingConfig:
    # --- Hardware & Precision ---
    GPU_IDS = [1] # 示例：根据你的GPU调整
    PRIMARY_GPU_ID = GPU_IDS[0] if GPU_IDS else 0
    NUM_GPUS = len(GPU_IDS) if torch.cuda.is_available() and GPU_IDS else 0
    PRIMARY_DEVICE_NAME = f"cuda:{PRIMARY_GPU_ID}" if NUM_GPUS > 0 else "cpu"
    MIXED_PRECISION_TYPE = "bf16" # "bf16", "fp16", or "no" for fp32 (影响 autocast 的 dtype)

    # --- Data ---
    ROOT_DIR = "/cwStorage/nodecw_group/jijh/hest_output" # 你的图像根目录
    IMAGE_EXTS = ['.png', '.jpg', '.jpeg']
    PRECOMPUTE_MAX_SAMPLES = None # None 表示使用所有找到的图像

    # --- GigaPath Specific ---
    GIGAPATH_MODEL_NAME = 'hf_hub:prov-gigapath/prov-gigapath'
    GIGAPATH_CACHE_DIR = '/home1/jijh/diffusion_project/huggingface_repo/prov-gigapath' # GigaPath模型缓存目录
    GIGAPATH_INPUT_SIZE_RESIZE = 256
    GIGAPATH_INPUT_SIZE_CROP = 224
    GIGAPATH_NORMALIZATION_MEAN = (0.485, 0.456, 0.406)
    GIGAPATH_NORMALIZATION_STD = (0.229, 0.224, 0.225)

    # --- Feature Pre-computation (GigaPath) ---
    FEATURE_DIR = "/cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook" # 特征保存目录 (修改了名称以区分)
    PRECOMPUTE_BATCH_SIZE = 128 # 预计算时的批处理大小
    FEATURE_SAVE_PRECISION = torch.bfloat16 # 目标保存精度

    NUM_WORKERS = 16 # DataLoader 的 num_workers
    # ... 其他你可能需要的配置 ...

# %% [markdown]
# # CELL 3: GigaPath 模型加载函数 和 Dataset 定义

# %%
def get_gigapath_model(config: TrainingConfig, device):
    """加载预训练的 GigaPath 模型"""
    print(f"正在从 {config.GIGAPATH_MODEL_NAME} 加载 GigaPath 模型...")
    model = timm.create_model(
        model_name=config.GIGAPATH_MODEL_NAME,
        pretrained=True,
        cache_dir=config.GIGAPATH_CACHE_DIR
    )
    model = model.to(device)
    model.eval() # 设置为评估模式
    print("GigaPath 模型加载完毕并已移至设备。")
    return model

class GigapathImageDataset(Dataset):
    """
    从子目录加载图像，并应用 GigaPath 特定的转换。
    返回图像张量和原始图像路径。
    """
    def __init__(self, root_dir, config: TrainingConfig, max_samples=None):
        self.root_dir = root_dir
        self.image_paths = []
        if not os.path.isdir(root_dir):
             raise FileNotFoundError(f"根目录未找到: {root_dir}")

        subfolders = [os.path.join(root_dir, d) for d in os.listdir(root_dir)
                      if os.path.isdir(os.path.join(root_dir, d))]
        if not subfolders:
            print(f"警告: 在 {root_dir} 中未找到子文件夹。将直接在 root_dir 中搜索。")
            subfolders = [root_dir]

        print(f"正在以下路径搜索图像: {subfolders}")
        all_paths = []
        # 在 Notebook 中，如果图像数量巨大，这里的 tqdm 可能会比较慢，是正常的
        for folder in notebook_tqdm(subfolders, desc="扫描图像文件夹"):
            for ext in config.IMAGE_EXTS:
                all_paths.extend(glob.glob(os.path.join(folder, f'*{ext}')))

        if not all_paths:
             raise FileNotFoundError(f"在 {root_dir} 及其子目录中未找到扩展名为 {config.IMAGE_EXTS} 的图像。")

        self.image_paths = all_paths
        print(f"找到 {len(self.image_paths)} 张图像。")

        if max_samples is not None and len(self.image_paths) > max_samples:
            print(f"从找到的 {len(self.image_paths)} 张图像中采样 {max_samples} 张。")
            self.image_paths = random.sample(self.image_paths, max_samples)
        print(f"GigapathImageDataset 初始化完毕，包含 {len(self.image_paths)} 张图像。")

        self.transform = transforms.Compose([
            transforms.Resize(config.GIGAPATH_INPUT_SIZE_RESIZE, interpolation=transforms.InterpolationMode.BICUBIC),
            transforms.CenterCrop(config.GIGAPATH_INPUT_SIZE_CROP),
            transforms.ToTensor(),
            transforms.Normalize(mean=config.GIGAPATH_NORMALIZATION_MEAN, std=config.GIGAPATH_NORMALIZATION_STD)
        ])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        try:
            image = Image.open(img_path).convert("RGB")
            image = self.transform(image)
            return image, img_path
        except Exception as e:
            print(f"加载图像 {img_path} 时出错: {e}")
            return None, None

# %% [markdown]
# # CELL 4: GigaPath 特征预计算和保存函数定义

# %%
def precompute_and_save_gigapath_features(gigapath_model, config: TrainingConfig, device):
    """
    使用 GigaPath 模型编码图像，并将特征保存到磁盘。
    """
    gigapath_model.eval()

    save_dtype = config.FEATURE_SAVE_PRECISION
    if save_dtype == torch.bfloat16 and not (device.type == 'cuda' and torch.cuda.is_bf16_supported()):
        print(f"警告: 配置要求 FEATURE_SAVE_PRECISION=bf16, 但在 {device} 上不受支持。回退到 float16。")
        save_dtype = torch.float16
    elif save_dtype not in [torch.float16, torch.bfloat16, torch.float32]:
         print(f"警告: 不支持的 FEATURE_SAVE_PRECISION {save_dtype}。回退到 float16。")
         save_dtype = torch.float16
    if device.type == 'cpu' and save_dtype != torch.float32:
        print(f"警告: CPU模式下，特征将以 float32 保存，而非配置的 {save_dtype}。")
        save_dtype = torch.float32

    print(f"--- 开始 GigaPath 特征预计算 (保存为 {save_dtype}，镜像结构) ---")
    
    precompute_dataset = GigapathImageDataset(
        root_dir=config.ROOT_DIR,
        config=config,
        max_samples=config.PRECOMPUTE_MAX_SAMPLES
    )

    def precompute_collate_fn(batch):
        filtered_batch = [item for item in batch if item[0] is not None and item[1] is not None]
        if not filtered_batch: return None, None
        images = torch.stack([item[0] for item in filtered_batch])
        paths = [item[1] for item in filtered_batch]
        return images, paths

    precompute_dataloader = DataLoader(
        precompute_dataset, batch_size=config.PRECOMPUTE_BATCH_SIZE, shuffle=False,
        num_workers=config.NUM_WORKERS, pin_memory=(device.type == 'cuda'), collate_fn=precompute_collate_fn
    )

    feature_dir = config.FEATURE_DIR
    os.makedirs(feature_dir, exist_ok=True)
    print(f"特征将镜像结构保存在: {feature_dir}")

    count = 0
    amp_enabled = (device.type == 'cuda' and config.MIXED_PRECISION_TYPE != "no")
    if config.MIXED_PRECISION_TYPE == "bf16" and torch.cuda.is_bf16_supported():
        amp_dtype = torch.bfloat16
    elif config.MIXED_PRECISION_TYPE == "fp16":
        amp_dtype = torch.float16
    else:
        amp_dtype = torch.float32
        if amp_enabled and amp_dtype == torch.float32:
            amp_enabled = False

    start_time = time.time()
    progress_bar = notebook_tqdm(precompute_dataloader, desc="预计算 GigaPath 特征")

    with torch.no_grad():
        for images, img_paths in progress_bar:
            if images is None or not img_paths:
                continue
            
            images = images.to(device)

            with autocast(enabled=amp_enabled, dtype=amp_dtype):
                features = gigapath_model(images)
            
            features_cpu = features.detach().to('cpu', dtype=save_dtype)

            for i, img_path in enumerate(img_paths):
                try:
                    relative_img_path = os.path.relpath(img_path, config.ROOT_DIR)
                    relative_dir, img_filename = os.path.split(relative_img_path)
                    img_basename = os.path.splitext(img_filename)[0]
                    target_feature_subdir = os.path.join(config.FEATURE_DIR, relative_dir)
                    feature_filename = img_basename + ".pt"
                    feature_save_path = os.path.join(target_feature_subdir, feature_filename)
                    os.makedirs(target_feature_subdir, exist_ok=True)
                    
                    tensor_to_save = features_cpu[i].clone()
                    torch.save(tensor_to_save, feature_save_path)
                    count += 1
                except Exception as e:
                    print(f"\n处理/保存图像 {img_path} 的特征时出错: {e}")
            progress_bar.set_postfix({"已保存": count})

    total_time = time.time() - start_time
    print(f"--- GigaPath 特征预计算完成 ---")
    print(f"已保存 {count} 个特征 (格式: {save_dtype})，镜像结构于 {feature_dir}")
    print(f"总耗时: {str(datetime.timedelta(seconds=int(total_time)))}")

# %% [markdown]
# # %% CELL 5: 配置实例化、设备设置 和 GigaPath 模型加载

# %%
config = TrainingConfig()
print("TrainingConfig 已加载。")

# --- 设备设置 ---
if config.NUM_GPUS > 0 and torch.cuda.is_available():
    precompute_device = torch.device(config.PRIMARY_DEVICE_NAME)
    try:
        torch.cuda.set_device(precompute_device) # 尝试设置当前CUDA设备
        print(f"将使用主 GPU 进行预计算: {torch.cuda.get_device_name(precompute_device)}")
        if config.FEATURE_SAVE_PRECISION == torch.bfloat16:
            if torch.cuda.is_bf16_supported():
                print("此 GPU 支持 bf16 格式。")
            else:
                print("警告: 此 GPU 不支持 bf16。FEATURE_SAVE_PRECISION 将在函数内部回退。")
    except Exception as e:
        print(f"设置 GPU {config.PRIMARY_DEVICE_NAME} 失败: {e}. 回退到 CPU。")
        precompute_device = torch.device("cpu")
        config.NUM_GPUS = 0 # 更新配置以反映实际情况
        print("将使用 CPU 进行预计算。")
        if config.FEATURE_SAVE_PRECISION != torch.float32:
            print(f"警告: CPU 模式下，特征将以 float32 保存，而非配置的 {config.FEATURE_SAVE_PRECISION}。")
            config.FEATURE_SAVE_PRECISION = torch.float32
else:
    precompute_device = torch.device("cpu")
    print("将使用 CPU 进行预计算。")
    if config.FEATURE_SAVE_PRECISION != torch.float32:
        print(f"警告: CPU 模式下，特征将以 float32 保存，而非配置的 {config.FEATURE_SAVE_PRECISION}。")
        config.FEATURE_SAVE_PRECISION = torch.float32

print(f"预计算设备设置为: {precompute_device}")

# --- 加载 GigaPath 模型 ---
# 将模型加载放到一个 try-except 块中，以便更好地处理可能的错误
try:
    gigapath_model = get_gigapath_model(config, precompute_device)
except Exception as e:
    print(f"加载 GigaPath 模型时发生错误: {e}")
    gigapath_model = None # 明确设为 None，以便后续检查
# Out:
# TrainingConfig 已加载。
# 将使用主 GPU 进行预计算: NVIDIA H100 PCIe
# 此 GPU 支持 bf16 格式。
# 预计算设备设置为: cuda:0
# 正在从 hf_hub:prov-gigapath/prov-gigapath 加载 GigaPath 模型...
# GigaPath 模型加载完毕并已移至设备。

# %% [markdown]
# # Cell 6: Main Execution

# %%
if gigapath_model: # 仅当模型成功加载时才执行
    # 可选：用户确认，防止意外覆盖
    # user_input = input(f"预计算会将特征保存到 {config.FEATURE_DIR}，可能覆盖现有文件。是否继续? (y/n): ").lower()
    # if user_input == 'y':
    #     precompute_and_save_gigapath_features(gigapath_model, config, precompute_device)
    # else:
    #     print("用户请求跳过特征预计算。")
    precompute_and_save_gigapath_features(gigapath_model, config, precompute_device) # 直接执行，如果需要确认，取消上面注释
else:
    print("GigaPath 模型未成功加载，跳过预计算步骤。")
# Out:
# --- 开始 GigaPath 特征预计算 (保存为 torch.bfloat16，镜像结构) ---
# 正在以下路径搜索图像: ['/cwStorage/nodecw_group/jijh/hest_output/TENX105_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI861_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI146_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI192_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI563_tiles', '/cwStorage/nodecw_group/jijh/hest_output/SPA45_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI462_expr', '/cwStorage/nodecw_group/jijh/hest_output/MISC107_tiles', '/cwStorage/nodecw_group/jijh/hest_output/MISC58_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI434_tiles', '/cwStorage/nodecw_group/jijh/hest_output/TENX24_expr', '/cwStorage/nodecw_group/jijh/hest_output/MEND35_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI296_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI492_expr', '/cwStorage/nodecw_group/jijh/hest_output/SPA3_expr', '/cwStorage/nodecw_group/jijh/hest_output/TENX136_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI44_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI61_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI62_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI627_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI161_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI298_expr', '/cwStorage/nodecw_group/jijh/hest_output/MEND82_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI783_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI865_expr', '/cwStorage/nodecw_group/jijh/hest_output/TENX121_expr', '/cwStorage/nodecw_group/jijh/hest_output/MISC121_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI371_tiles', '/cwStorage/nodecw_group/jijh/hest_output/SPA117_expr', '/cwStorage/nodecw_group/jijh/hest_output/TENX78_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI729_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI219_expr', '/cwStorage/nodecw_group/jijh/hest_output/SPA31_expr', '/cwStorage/nodecw_group/jijh/hest_output/TENX147_tiles', '/cwStorage/nodecw_group/jijh/hest_output/MISC41_expr', '/cwStorage/nodecw_group/jijh/hest_output/MEND79_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI114_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI32_expr', '/cwStorage/nodecw_group/jijh/hest_output/MEND90_expr', '/cwStorage/nodecw_group/jijh/hest_output/TENX114_tiles', '/cwStorage/nodecw_group/jijh/hest_output/TENX72_tiles', '/cwStorage/nodecw_group/jijh/hest_output/SPA46_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI657_expr', '/cwStorage/nodecw_group/jijh/hest_output/MISC115_tiles', '/cwStorage/nodecw_group/jijh/hest_output/INT12_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI484_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI365_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI860_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI857_tiles', '/cwStorage/nodecw_group/jijh/hest_output/SPA71_tiles', '/cwStorage/nodecw_group/jijh/hest_output/TENX119_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI310_expr', '/cwStorage/nodecw_group/jijh/hest_output/MEND148_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI806_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI688_tiles', '/cwStorage/nodecw_group/jijh/hest_output/TENX139_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI244_tiles', '/cwStorage/nodecw_group/jijh/hest_output/TENX24_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI402_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI301_expr', '/cwStorage/nodecw_group/jijh/hest_output/MISC66_expr', '/cwStorage/nodecw_group/jijh/hest_output/SPA42_expr', '/cwStorage/nodecw_group/jijh/hest_output/TENX98_tiles', '/cwStorage/nodecw_group/jijh/hest_output/MEND71_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI352_expr', '/cwStorage/nodecw_group/jijh/hest_output/NCBI765_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI188_tiles', '/cwStorage/nodecw_group/jijh/hest_output/MEND96_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI109_tiles', '/cwStorage/nodecw_group/jijh/hest_output/NCBI69_exp ...
# 扫描图像文件夹:   0%|          | 0/2458 [00:00<?, ?it/s]
# 找到 2104169 张图像。
# GigapathImageDataset 初始化完毕，包含 2104169 张图像。
# 特征将镜像结构保存在: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook
# 预计算 GigaPath 特征:   0%|          | 0/16439 [00:00<?, ?it/s]
# /tmp/ipykernel_27448/643584036.py:63: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=amp_enabled, dtype=amp_dtype):

# %%
# Read the graph data from /cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6/MEND123_graph.pt
# 这里的路径和文件名需要根据实际情况调整
graph_file_path = "/cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6/MEND123_graph.pt"
if os.path.exists(graph_file_path):
    print(f"正在读取图数据文件: {graph_file_path}")
    graph_data = torch.load(graph_file_path, map_location='cpu')
    if hasattr(graph_data, 'latent_paths'):
        print(f"图数据中包含 'latent_paths' 属性，长度为 {len(graph_data.latent_paths)}。")
    else:
        print("图数据中未找到 'latent_paths' 属性。")
else:
    print(f"❌ 错误: 图数据文件 '{graph_file_path}' 不存在。请检查路径和文件名。")
# Out:
# 正在读取图数据文件: /cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6/MEND123_graph.pt
# 图数据中包含 'latent_paths' 属性，长度为 1490。
# /tmp/ipykernel_27448/3798043990.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   graph_data = torch.load(graph_file_path, map_location='cpu')

# %%
graph_data
# Out:
# Data(x=[1490, 50], edge_index=[2, 7920], coords=[1490, 2], spot_ids=[1490], latent_paths=[1490], sample_id='MEND123')

# %% [markdown]
# # Run the train scripts

# %%
# Cell 1: Imports for CLIP Training
import os
import sys
import random
import glob
import datetime
import time
import subprocess
import shlex
import warnings
from pathlib import Path
# os.chdir("/home1/jijh/diffusion_project/ADiffusion") # If running script directly
import numpy as np
from tqdm.auto import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data, Batch
# from torch_geometric.loader import DataLoader as PyGDataLoader # Defined in script
from torch_geometric.nn import GPSConv, GATConv # For GraphConditioner

# Filter warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)

# %matplotlib inline # If you plan to add inline plotting for something

# %% [markdown]
# ## Training configuration

# %%
# Cell 2: Configuration Class for CLIP Training
class TrainingConfigCLIP:
    # --- Hardware & Precision ---
    GPU_IDS = [0, 1] # <-- SPECIFY GPU(s) FOR CLIP TRAINING
    PRIMARY_GPU_ID = GPU_IDS[0] if GPU_IDS else 0
    NUM_GPUS = len(GPU_IDS) if torch.cuda.is_available() and GPU_IDS else 0
    PRIMARY_DEVICE_NAME = f"cuda:{PRIMARY_GPU_ID}" if NUM_GPUS > 0 else "cpu"
    MIXED_PRECISION_TYPE = "bf16" # "bf16", "fp16", or "no"
    DDP_MASTER_PORT = 29501 # Choose a different unused port for CLIP DDP

    # --- Data Paths ---
    # Input GigaPath Features (from your GigaPath precomputation)
    GIGAPATH_FEATURE_DIR = "/cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook"
    # Input Processed Graphs (from your graph preprocessing notebook)
    GRAPH_DATA_DIR = "/cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6"
    # Base directory of original VAE latents (used to reconstruct GigaPath feature paths if necessary)
    # This is needed if graph_data.latent_paths store absolute paths to VAE latents
    ORIGINAL_LATENT_DIR_BASE_FOR_PATH_RECONSTRUCTION = "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16"


    # --- GigaPath Feature Info ---
    GIGAPATH_FEATURE_DIM = 1536 # Or 768, depending on the GigaPath model used (e.g., prov-gigapath uses 1024 for CLS token)
                                # Check the output dimension of your GigaPath features

    # --- Graph Conditioner (Text/Context Encoder) ---
    # These parameters define the GraphConditioner architecture
    PCA_N_COMPS = 50 # Should match the PCA used for graph node features
    CONDITIONER_INPUT_DIM = PCA_N_COMPS
    CONDITIONER_HIDDEN_DIM = 256
    CONDITIONER_N_LAYERS = 4
    CONDITIONER_N_HEADS = 4
    CONDITIONER_ATTN_DROPOUT = 0.1
    # CONDITIONER_OUTPUT_DIM will be CLIP_EMBED_DIM (see below)

    # --- CLIP Model Specific ---
    CLIP_EMBED_DIM = 512 # Dimension of the common embedding space (e.g., 512, 768)
    IMAGE_ENCODER_MLP_LAYERS = [GIGAPATH_FEATURE_DIM, 1024, CLIP_EMBED_DIM] # Example: GigaPath_dim -> 1024 -> CLIP_dim
    # Logit scale for contrastive loss (learnable)
    CLIP_LOGIT_SCALE_INIT = np.log(1 / 0.07) # Standard CLIP initialization

    # --- Training Script Config ---
    CLIP_BATCH_SIZE_PER_GPU = 64 # Adjust based on GPU memory (more than diffusion usually)
    CLIP_NUM_EPOCHS = 50
    CLIP_LEARNING_RATE = 1e-4 # CLIP often uses smaller LRs
    CLIP_WEIGHT_DECAY = 0.01
    ACCUMULATION_STEPS = 2
    NUM_WORKERS = 16

    # --- 【新增】调试和复现性设置 ---
    # 通过设置此值 > 0 来激活调试模式，仅在指定数量的图上进行训练。
    # 设置为 0 或负数则使用全部图进行训练。
    DEBUG_NUM_GRAPHS = 10  # <-- 在这里设置你想用于调试的图的数量，例如 10
    
    # 用于确保随机选择的图和训练中的其他随机过程是可复现的。
    SEED = 42 # <-- 在这里设置你的随机种子
    # --- 结束新增 ---

    # --- Logging & Saving (Script) ---
    CHECKPOINT_DIR = "/cwStorage/nodecw_group/jijh/model_path/clip_graph_gigapath_v1"
    LOG_DIR = "/cwStorage/nodecw_group/jijh/training_log/clip_graph_gigapath_v1"
    CHECKPOINT_FILENAME_PREFIX = "clip_graph_gigapath"
    TRAIN_SCRIPT_PATH = "/home1/jijh/diffusion_project/ADiffusion/src/pipeline/train_clip_graph_gigapath_ddp.py" # Path to NEW DDP script
    SAVE_INTERVAL_EPOCHS = 5
    LOG_INTERVAL_STEPS = 50 # Log basic stats every N optimizer steps

    @classmethod
    def get_script_args(cls):
        args = [
            f"--gigapath_feature_dir={cls.GIGAPATH_FEATURE_DIR}",
            f"--graph_data_dir={cls.GRAPH_DATA_DIR}",
            f"--original_latent_dir_base={cls.ORIGINAL_LATENT_DIR_BASE_FOR_PATH_RECONSTRUCTION}",
            f"--checkpoint_dir={cls.CHECKPOINT_DIR}",
            f"--log_dir={cls.LOG_DIR}",

            f"--epochs={cls.CLIP_NUM_EPOCHS}",
            f"--batch_size_per_gpu={cls.CLIP_BATCH_SIZE_PER_GPU}",
            f"--lr={cls.CLIP_LEARNING_RATE}",
            f"--weight_decay={cls.CLIP_WEIGHT_DECAY}",
            f"--accumulation_steps={cls.ACCUMULATION_STEPS}",
            f"--mixed_precision={cls.MIXED_PRECISION_TYPE}",
            f"--num_workers={cls.NUM_WORKERS}",

            f"--gigapath_feature_dim={cls.GIGAPATH_FEATURE_DIM}",
            f"--pca_n_comps={cls.PCA_N_COMPS}",
            f"--conditioner_input_dim={cls.CONDITIONER_INPUT_DIM}",
            f"--conditioner_hidden_dim={cls.CONDITIONER_HIDDEN_DIM}",
            f"--conditioner_output_dim={cls.CLIP_EMBED_DIM}", # Conditioner outputs to CLIP embedding dim
            f"--conditioner_n_layers={cls.CONDITIONER_N_LAYERS}",
            f"--conditioner_n_heads={cls.CONDITIONER_N_HEADS}",
            f"--conditioner_attn_dropout={cls.CONDITIONER_ATTN_DROPOUT}",

            f"--clip_embed_dim={cls.CLIP_EMBED_DIM}",
            f"--image_encoder_mlp_layers={','.join(map(str, cls.IMAGE_ENCODER_MLP_LAYERS))}",
            f"--clip_logit_scale_init={cls.CLIP_LOGIT_SCALE_INIT}",

            f"--save_interval={cls.SAVE_INTERVAL_EPOCHS}",
            f"--log_interval={cls.LOG_INTERVAL_STEPS}",
            f"--checkpoint_filename_prefix={cls.CHECKPOINT_FILENAME_PREFIX}",
        ]

        # --- 【修改】添加新的调试参数到命令行 ---
        # 总是添加seed以保证复现性
        args.append(f"--seed={cls.SEED}")
        
        # 只有在DEBUG_NUM_GRAPHS > 0时才添加这个参数，这样更干净
        if cls.DEBUG_NUM_GRAPHS > 0:
            args.append(f"--debug_num_graphs={cls.DEBUG_NUM_GRAPHS}")
        # --- 结束修改 ---

        return args

# --- Instantiate config ---
config_clip = TrainingConfigCLIP()
os.makedirs(config_clip.GRAPH_DATA_DIR, exist_ok=True) # Should already exist
os.makedirs(config_clip.GIGAPATH_FEATURE_DIR, exist_ok=True) # Should already exist
os.makedirs(config_clip.CHECKPOINT_DIR, exist_ok=True)
os.makedirs(config_clip.LOG_DIR, exist_ok=True)

# print("CLIP TrainingConfig loaded.")
# if not os.path.exists(config_clip.GIGAPATH_FEATURE_DIR) or not glob.glob(os.path.join(config_clip.GIGAPATH_FEATURE_DIR, "**/*.pt"), recursive=True):
#     print(f"WARNING: GigaPath feature directory {config_clip.GIGAPATH_FEATURE_DIR} is empty or does not exist!")
# if not os.path.exists(config_clip.GRAPH_DATA_DIR) or not glob.glob(os.path.join(config_clip.GRAPH_DATA_DIR, "*.pt")):
#     print(f"WARNING: Graph data directory {config_clip.GRAPH_DATA_DIR} is empty or does not exist!")

# %% [markdown]
# ## Clip model definition

# %%
# Cell 3: CLIP Model Definitions (Conceptual - for the script)

# --- Image Encoder (from GigaPath features) ---
class GigapathFeatureEncoder(nn.Module):
    def __init__(self, mlp_layers): # e.g., [gigapath_dim, 1024, clip_embed_dim]
        super().__init__()
        layers = []
        for i in range(len(mlp_layers) - 1):
            layers.append(nn.Linear(mlp_layers[i], mlp_layers[i+1]))
            if i < len(mlp_layers) - 2: # No ReLU after the last linear layer
                layers.append(nn.ReLU())
        self.projection = nn.Sequential(*layers)

    def forward(self, x):
        return self.projection(x)

# --- Graph/Text/Context Encoder (Your GraphConditioner) ---
# Re-use the GraphConditioner class from your diffusion script.
# Ensure its output_dim is config_clip.CLIP_EMBED_DIM.
# (Definition would be in the training script, not repeated here for brevity)
# class GraphConditioner(nn.Module): ... (as defined before)


# --- Full CLIP Model ---
class GraphGigapathCLIP(nn.Module):
    def __init__(self, gigapath_encoder, graph_conditioner, logit_scale_init):
        super().__init__()
        self.gigapath_encoder = gigapath_encoder
        self.graph_conditioner = graph_conditioner
        self.logit_scale = nn.Parameter(torch.ones([]) * logit_scale_init)

    def forward(self, gigapath_features, graph_batch, graph_node_indices):
        # gigapath_features: (batch_size, gigapath_feature_dim)
        # graph_batch: PyG Batch object
        # graph_node_indices: (batch_size,) global indices of target nodes in graph_batch

        image_embeddings = self.gigapath_encoder(gigapath_features)

        all_graph_node_embeddings = self.graph_conditioner(graph_batch)
        text_embeddings = all_graph_node_embeddings[graph_node_indices]

        # Normalized features
        image_embeddings = F.normalize(image_embeddings, p=2, dim=-1)
        text_embeddings = F.normalize(text_embeddings, p=2, dim=-1)

        return image_embeddings, text_embeddings, self.logit_scale.exp()

# %% [markdown]
# ## Test data loading for CLIP

# %%
# Cell 4: (Optional) Test data loading for CLIP

try:
    print("\n--- Testing Graph and GigaPath Feature Loading ---")
    example_graph_files = glob.glob(os.path.join(config_clip.GRAPH_DATA_DIR, "*_graph.pt"))
    if not example_graph_files:
        print("No graph files found in", config_clip.GRAPH_DATA_DIR)
    else:
        example_graph_path = random.choice(example_graph_files)
        print(f"Loading example graph: {example_graph_path}")
        example_graph = torch.load(example_graph_path, map_location='cpu')

        # Find a valid node with a latent_path
        valid_node_idx = -1
        original_vae_latent_path_for_node = None
        for idx, pth in enumerate(example_graph.latent_paths):
            if pth is not None: # Assuming pth is the full path to VAE latent
                 valid_node_idx = idx
                 original_vae_latent_path_for_node = pth
                 break

        if valid_node_idx == -1 or original_vae_latent_path_for_node is None:
            print("No valid latent_paths found in the example graph.")
        else:
            print(f"Found valid node {valid_node_idx} in graph.")
            print(f"  Original VAE latent path: {original_vae_latent_path_for_node}")

            # Construct the GigaPath feature path
            # This logic needs to be robust and match how features were saved
            relative_path_to_latent = os.path.relpath(
                original_vae_latent_path_for_node,
                config_clip.ORIGINAL_LATENT_DIR_BASE_FOR_PATH_RECONSTRUCTION
            )
            gigapath_feature_path = os.path.join(
                config_clip.GIGAPATH_FEATURE_DIR,
                relative_path_to_latent # This assumes the subfolder structure is identical
            )
            print(f"  Constructed GigaPath feature path: {gigapath_feature_path}")

            if os.path.exists(gigapath_feature_path):
                print("  GigaPath feature file EXISTS.")
                gp_feature = torch.load(gigapath_feature_path, map_location='cpu')
                print(f"  Loaded GigaPath feature: shape={gp_feature.shape}, dtype={gp_feature.dtype}")
                assert gp_feature.shape[0] == config_clip.GIGAPATH_FEATURE_DIM, \
                    f"Feature dim mismatch! Expected {config_clip.GIGAPATH_FEATURE_DIM}, got {gp_feature.shape[0]}"
            else:
                print(f"  GigaPath feature file NOT FOUND at: {gigapath_feature_path}")
                print(f"  Please check: ")
                print(f"    1. GigaPath features were precomputed to {config_clip.GIGAPATH_FEATURE_DIR}")
                print(f"    2. The relative path structure within GIGAPATH_FEATURE_DIR mirrors that of ORIGINAL_LATENT_DIR_BASE")
                print(f"    3. ORIGINAL_LATENT_DIR_BASE_FOR_PATH_RECONSTRUCTION ('{config_clip.ORIGINAL_LATENT_DIR_BASE_FOR_PATH_RECONSTRUCTION}') is correct.")


            # Test model instantiation (conceptual)
            print("\nInstantiating conceptual CLIP model parts...")
            dummy_gp_encoder = GigapathFeatureEncoder(config_clip.IMAGE_ENCODER_MLP_LAYERS)
            dummy_graph_conditioner = nn.Linear(config_clip.CONDITIONER_INPUT_DIM, config_clip.CLIP_EMBED_DIM) # Simplified
            print("Conceptual models instantiated.")

except Exception as e:
    print(f"Error during testing: {e}")
    import traceback
    traceback.print_exc()
# Out:
# --- Testing Graph and GigaPath Feature Loading ---
# Loading example graph: /cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6/MISC3_graph.pt
# Found valid node 0 in graph.
#   Original VAE latent path: /cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MISC3_tiles/MISC3_8521_9716.pt
#   Constructed GigaPath feature path: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook/MISC3_tiles/MISC3_8521_9716.pt
#   GigaPath feature file EXISTS.
#   Loaded GigaPath feature: shape=torch.Size([1536]), dtype=torch.bfloat16
#
# Instantiating conceptual CLIP model parts...
# Conceptual models instantiated.

# %% [markdown]
# ## Run the script

# %%
# Cell 5: Launch DDP Training Script for CLIP
print("\n--- Preparing to Launch DDP Training Script for CLIP ---")
config_clip = TrainingConfigCLIP() # Reload config

if not os.path.exists(config_clip.TRAIN_SCRIPT_PATH):
    print(f"Error: CLIP Training script '{config_clip.TRAIN_SCRIPT_PATH}' not found.")
    print("Please create this script (train_clip_graph_gigapath_ddp.py).")
else:
    if config_clip.NUM_GPUS == 0 or not config_clip.GPU_IDS:
        print("Error: No GPUs specified in config_clip.GPU_IDS or CUDA not available.")
    else:
        python_executable = sys.executable
        print(f"Using Python executable: {python_executable}")
        print(f"Attempting to use {config_clip.NUM_GPUS} GPUs with IDs: {config_clip.GPU_IDS}")

        modified_env = os.environ.copy()
        cuda_visible_devices = ",".join(map(str, config_clip.GPU_IDS))
        modified_env["CUDA_VISIBLE_DEVICES"] = cuda_visible_devices
        print(f"Setting CUDA_VISIBLE_DEVICES={cuda_visible_devices} for the subprocess.")

        cmd = [
            python_executable,
            "-m", "torch.distributed.run",
            f"--nproc_per_node={config_clip.NUM_GPUS}",
            f"--master_port={config_clip.DDP_MASTER_PORT}",
            config_clip.TRAIN_SCRIPT_PATH,
        ]
        cmd.extend(config_clip.get_script_args())

        print("\nLaunching command for CLIP training:")
        print(shlex.join(cmd))
        print("-" * 30 + "\nScript Output:\n" + "-" * 30)

        process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                                   text=True, bufsize=1, encoding='utf-8', errors='replace',
                                   env=modified_env)
        while True:
            output = process.stdout.readline()
            if output == '' and process.poll() is not None:
                break
            if output:
                try:
                    print(output.strip())
                except Exception as e_print:
                    print(f"[Encoding error in output: {e_print}]")
        rc = process.poll()
        print("-" * 30 + "\n--- CLIP Script Finished ---")
        if rc == 0:
            print("CLIP Training script finished successfully.")
        else:
            print(f"CLIP Training script exited with error code {rc}.")
# Out:
# --- Preparing to Launch DDP Training Script for CLIP ---
# Using Python executable: /public/home/jijh/micromamba/envs/gpu_env/bin/python
# Attempting to use 2 GPUs with IDs: [0, 1]
# Setting CUDA_VISIBLE_DEVICES=0,1 for the subprocess.
#
# Launching command for CLIP training:
# /public/home/jijh/micromamba/envs/gpu_env/bin/python -m torch.distributed.run --nproc_per_node=2 --master_port=29501 /home1/jijh/diffusion_project/ADiffusion/src/pipeline/train_clip_graph_gigapath_ddp.py --gigapath_feature_dir=/cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook --graph_data_dir=/cwStorage/nodecw_group/jijh/hest_graph_data_pca50_knn6 --original_latent_dir_base=/cwStorage/nodecw_group/jijh/hest_output_latents_bf16 --checkpoint_dir=/cwStorage/nodecw_group/jijh/model_path/clip_graph_gigapath_v1 --log_dir=/cwStorage/nodecw_group/jijh/training_log/clip_graph_gigapath_v1 --epochs=50 --batch_size_per_gpu=64 --lr=0.0001 --weight_decay=0.01 --accumulation_steps=2 --mixed_precision=bf16 --num_workers=16 --gigapath_feature_dim=1536 --pca_n_comps=50 --conditioner_input_dim=50 --conditioner_hidden_dim=256 --conditioner_output_dim=512 --conditioner_n_layers=4 --conditioner_n_heads=4 --conditioner_attn_dropout=0.1 --clip_embed_dim=512 --image_encoder_mlp_layers=1536,1024,512 --clip_logit_scale_init=2.659260036932778 --save_interval=5 --log_interval=50 --checkpoint_filename_prefix=clip_graph_gigapath --seed=42 --debug_num_graphs=10
# ------------------------------
# Script Output:
# ------------------------------
# WARNING:__main__:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# DDP Setup: Rank 0/2, Local Rank 0, Device cuda:0
# Using AMP: True, dtype: torch.bfloat16
# TensorBoard logs at: /cwStorage/nodecw_group/jijh/training_log/clip_graph_gigapath_v1/20250607-012435
# Initializing CLIP dataset...
# Found 209 graph files.
# --- DEBUG MODE ACTIVATED ---
# Rank 0: Randomly selected 10 graphs (out of 209) using seed 42.
# ---
# DDP Setup: Rank 1/2, Local Rank 1, Device cuda:1
#
# Rank 0 Scanning Graphs:   0%|          | 0/5 [00:00<?, ?it/s]DEBUG (Rank 0): GigaPath feature NOT FOUND.
# Graph: MISC9_graph.pt, Node Index: 549
# Attempted path: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook/MISC9_tiles/MISC9_6025_3192.pt
# Derived from:
# current_sample_id: 'MISC9'
# x_coord_str: '6025', y_coord_str: '3192'
# (Coords were from graph_data.coords: [6025.3720703125, 3192.5])
# Original path info in graph: None
# --------------------
# DEBUG (Rank 0): GigaPath feature NOT FOUND.
# Graph: MISC9_graph.pt, Node Index: 2124
# Attempted path: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook/MISC9_tiles/MISC9_10201_9330.pt
# Derived from:
# current_sample_id: 'MISC9'
# x_coord_str: '10201', y_coord_str: '9330'
# (Coords were from graph_data.coords: [10201.361328125, 9330.5])
# Original path info in graph: None
# --------------------
# DEBUG (Rank 0): GigaPath feature NOT FOUND.
# Graph: MISC9_graph.pt, Node Index: 2261
# Attempted path: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook/MISC9_tiles/MISC9_4412_10747.pt
# Derived from:
# current_sample_id: 'MISC9'
# x_coord_str: '4412', y_coord_str: '10747'
# (Coords were from graph_data.coords: [4411.5, 10747.130859375])
# Original path info in graph: None
# --------------------
# DEBUG (Rank 0): GigaPath feature NOT FOUND.
# Graph: MISC9_graph.pt, Node Index: 2502
# Attempted path: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook/MISC9_tiles/MISC9_4276_10266.pt
# Derived from:
# current_sample_id: 'MISC9'
# x_coord_str: '4276', y_coord_str: '10266'
# (Coords were from graph_data.coords: [4275.6953125, 10266.5])
# Original path info in graph: None
# --------------------
# DEBUG (Rank 0): GigaPath feature NOT FOUND.
# Graph: MISC9_graph.pt, Node Index: 4632
# Attempted path: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook/MISC9_tiles/MISC9_4960_11469.pt
# Derived from:
# current_sample_id: 'MISC9'
# x_coord_str: '4960', y_coord_str: '11469'
# (Coords were from graph_data.coords: [4959.5, 11469.4794921875])
# Original path info in graph: None
# --------------------
#
# Rank 0 Scanning Graphs:  20%|██        | 1/5 [00:02<00:09,  2.31s/it]DEBUG (Rank 0): GigaPath feature NOT FOUND.
# Graph: TENX86_graph.pt, Node Index: 5122
# Attempted path: /cwStorage/nodecw_group/jijh/hest_output_gigapath_features_bf16_notebook/TENX86_tiles/TENX86_28476_20304.pt
# Derived from:
# current_sample_id: 'TENX86'
# x_coord_str: '28476', y_coord_str: '20304'
# (Coords were from graph_data.coords: [28476.0, 20304.0])
# Original path info in graph: None
# --------------------
#
# Rank 0 Scanning Graphs:  40%|████      | 2/5 [00:04<00:07,  2.44s/it]
# Rank 0 Scanning Graphs:  60%|██████    | 3/5 [00:05<00:02,  1.46s/it]
# Rank 0 Scanning Graphs:  80%|████████  | 4/5 [00:05<00:01,  1.01s/it]
# Rank 0 Scanning Graphs: 100%|██████████| 5/5 [00:07<00:00,  1.39s/it]
# Rank 0 Scanning Graphs: 100%|██████████| 5/5 [00:07<00:00,  1.51s/it]
# --- Rank 0 Dataset Scan Summary ---
# Processed graphs: 5
# Total items (node, feature pairs) found: 15224
# Graphs skipped (missing critical attributes): 0
# Nodes skipped (ID or coordinate determination error): 0
# Nodes skipped (constructed GigaPath feature path not exist): 6
# All ranks have completed dataset initialization.
# CLIP DataLoader initialized.
# LR Scheduler: CosineAnnealingLR, total steps: 2950
# Resuming CLIP training from checkpoint: /cwStorage/nodecw_group/jijh/model_path/clip_graph_gigapath_v1/clip_graph_gigapath_ep35_step70400_bs64x1_lr0.0001.pt
# Resuming from Epoch 35, Global Step 70400
# Fast-forwarding LR scheduler to step 70400...
# LR Scheduler state advanced. Current LR: 1.86e-05
#
# ==================== STARTING CLIP TRAINING ====================
#
# Epoch 36/50:   0%|          | 0/118 [00:00<?, ?it/s][rank0]:[W607 01:25:08.023821001 reducer.cpp:1400] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
#
# Epoch 36/50:   0%|          | 0/118 [00:20<?, ?it/s, loss=4.1664, lr=1.86e-05, step=70400]
# Epoch 36/50:   1%|          | 1/118 [00:20<40:29, 20.77s/it, loss=4.1664, lr=1.86e-05, step=70400][rank1]:[W607 01:25:19.007600587 reducer.cpp:1400] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
#
# Epoch 36/50:   1%|          | 1/118 [00:34<40:29, 20.77s/it, loss=4.1616, lr=1.86e-05, step=70401]
# Epoch 36/50:   2%|▏         | 2/118 [00:34<31:43, 16.41s/it, loss=4.1616, lr=1.86e-05, step=70401]
# Epoch 36/50:   2%|▏         | 2/118 [00:37<31:43, 16.41s/it, loss=4.1870, lr=1.86e-05, step=70401]
# Epoch 36/50:   3%|▎         | 3/118 [00:37<20:21, 10.62s/it, loss=4.1870, lr=1.86e-05, step=70401]
# Epoch 36/50:   3%|▎         | 3/118 [00:43<20:21, 10.62s/it, loss=4.1777, lr=1.86e-05, step=70402]
# Epoch 36/50:   3%|▎         | 4/118 [00:43<16:33,  8.72s/it, loss=4.1777, lr=1.86e-05, step=70402]
# Epoch 36/50:   3%|▎         | 4/118 [00:49<16:33,  8.72s/it, loss=4.1621, lr=1.86e-05, step=70402]
# Epoch 36/50:   4%|▍         | 5/118 [00:49<14:26,  7.67s/it, loss=4.1621, lr=1.86e-05, step=70402]
# Epoch 36/50:   4%|▍         | 5/118 [00:56<14:26,  7.67s/it, loss=4.2018, lr=1.86e-05, step=70403]
# Epoch 36/50:   5%|▌         | 6/118 [00:56<13:55,  7.46s/it, loss=4.2018, lr=1.86e-05, step=70403]
# Epoch 36/50:   5%|▌         | 6/118 [01:01<13:55,  7.46s/it, loss=4.1541, lr=1.86e-05, step=70403]
# Epoch 36/50:   6%|▌         | 7/118 [01:01<12:30,  6.76s/it, loss=4.1541, lr=1.86e-05, step=70403]
# Epoch 36/50:   6%|▌         | 7/118 [01:14<12:30,  6.76s/it, loss=4.0688, lr=1.86e-05, step=70404]
# Epoch 36/50:   7%|▋         | 8/118 [01:14<15:42,  8.57s/it, loss=4.0688, lr=1.86e-05, step=70404]
# Epoch 36/50:   7%|▋         | 8/118 [01:22<15:42,  8.57s/it, loss=4.1866, lr=1.86e-05, step=70404]
# Epoch 36/50:   8%|▊         | 9/118 [01:22<15:10,  8.36s/it, loss=4.1866, lr=1.86e-05, step=70404]
# Epoch 36/50:   8%|▊         | 9/118 [01:28<15:10,  8.36s/it, loss=4.0684, lr=1.86e-05, step=70405]
# Epoch 36/50:   8%|▊         | 10/118 [01:28<13:46,  7.65s/it, loss=4.0684, lr=1.86e-05, step=70405]
# Epoch 36/50:   8%|▊         | 10/118 [01:31<13:46,  7.65s/it, loss=4.1674, lr=1.86e-05, step=70405]
# Epoch 36/50:   9%|▉         | 11/118 [01:31<11:16,  6.32s/it, loss=4.1674, lr=1.86e-05, step=70405]
# Epoch 36/50:   9%|▉         | 11/118 [01:37<11:16,  6.32s/it, loss=4.2094, lr=1.86e-05, step=70406]
# Epoch 36/50:  10%|█         | 12/118 [01:37<10:48,  6.12s/it, loss=4.2094, lr=1.86e-05, step=70406]
# Epoch 36/50:  10%|█         | 12/118 [01:52<10:48,  6.12s/it, loss=4.1741, lr=1.86e-05, step=70406]
# Epoch 36/50:  11%|█         | 13/118 [01:52<15:18,  8.75s/it, loss=4.1741, lr=1.86e-05, step=70406]
# Epoch 36/50:  11%|█         | 13/118 [01:58<15:18,  8.75s/it, loss=4.2162, lr=1.86e-05, step=70407]
# Epoch 36/50:  12%|█▏        | 14/118 [01:58<13:47,  7.96s/it, loss=4.2162, lr=1.86e-05, step=70407]
# Epoch 36/50:  12%|█▏        | 14/118 [02:00<13:47,  7.96s/it, loss=4.1995, lr=1.86e-05, step=70407]
# Epoch 36/50:  13%|█▎        | 15/118 [02:00<10:50,  6.32s/it, loss=4.1995, lr=1.86e-05, step=70407]
# Epoch 36/50:  13%|█▎        | 15/118 [02:03<10:50,  6.32s/it, loss=4.1002, lr=1.86e-05, step=70408]
# Epoch 36/50:  14%|█▎        | 16/118 [02:03<08:53,  5.23s/it, loss=4.1002, lr=1.86e-05, step=70408]
# Epoch 36/50:  14%|█▎        | 16/118 [02:05<08:53,  5.23s/it, loss=4.0797, lr=1.86e-05, step=70408]
# Epoch 36/50:  14%|█▍        | 17/118 [02:05<07:21,  4.37s/it, loss=4.0797, lr=1.86e-05, step=70408]
# Epoch 36/50:  14%|█▍        | 17/118 [02:12<07:21,  4.37s/it, loss=4.1494, lr=1.86e-05, step=70409]
# Epoch 36/50:  15%|█▌        | 18/118 [02:12<08:29,  5.10s/it, loss=4.1494, lr=1.86e-05, step=70409]
# Epoch 36/50:  15%|█▌        | 18/118 [02:19<08:29,  5.10s/it, loss=4.1788, lr=1.86e-05, step=70409]
# Epoch 36/50:  16%|█▌        | 19/118 [02:19<09:18,  5.64s/it, loss=4.1788, lr=1.86e-05, step=70409]
# Epoch 36/50:  16%|█▌        | 19/118 [02:24<09:18,  5.64s/it, loss=4.2023, lr=1.86e-05, step=70410]
# Epoch 36/50:  17%|█▋        | 20/118 [02:24<09:00,  5.51s/it, loss=4.2023, lr=1.86e-05, step=70410]
# Epoch 36/50:  17%|█▋        | 20/118 [02:29<09:00,  5.51s/it, loss=4.1638, lr=1.86e-05, step=70410]
# Epoch 36/50:  18%|█▊        | 21/118 [02:29<08:24,  5.21s/it, loss=4.1638, lr=1.86e-05, step=70410]
# Epoch 36/50:  18%|█▊        | 21/118 [02:34<08:24,  5.21s/it, loss=4.1855, lr=1.86e-05, step=70411]
# Epoch 36/50:  19%|█▊        | 22/118 [02:34<08:28,  5.30s/it, loss=4.1855, lr=1.86e-05, step=70411]
# Epoch 36/50:  19%|█▊        | 22/118 [02:44<08:28,  5.30s/it, loss=4.1858, lr=1.86e-05, step=70411]
# Epoch 36/50:  19%|█▉        | 23/118 [02:44<10:41,  6.75s/it, loss=4.1858, lr=1.86e-05, step=70411]
# Epoch 36/50:  19%|█▉        | 23/118 [03:05<10:41,  6.75s/it, loss=4.1588, lr=1.86e-05, step=70412]
# Epoch 36/50:  20%|██        | 24/118 [03:05<17:19, 11.06s/it, loss=4.1588, lr=1.86e-05, step=70412]
# Epoch 36/50:  20%|██        | 24/118 [03:13<17:19, 11.06s/it, loss=4.2058, lr=1.86e-05, step=70412]
# Epoch 36/50:  21%|██        | 25/118 [03:13<15:32, 10.02s/it, loss=4.2058, lr=1.86e-05, step=70412]
# Epoch 36/50:  21%|██        | 25/118 [03:17<15:32, 10.02s/it, loss=4.1779, lr=1.86e-05, step=70413]
# Epoch 36/50:  22%|██▏       | 26/118 [03:17<12:44,  8.31s/it, loss=4.1779, lr=1.86e-05, step=70413]
# Epoch 36/50:  22%|██▏       | 26/118 [03:25<12:44,  8.31s/it, loss=4.1815, lr=1.86e-05, step=70413]
# Epoch 36/50:  23%|██▎       | 27/118 [03:25<12:06,  7.99s/it, loss=4.1815, lr=1.86e-05, step=70413]
# Epoch 36/50:  23%|██▎       | 27/118 [03:29<12:06,  7.99s/it, loss=4.1523, lr=1.86e-05, step=70414]
# Epoch 36/50:  24%|██▎       | 28/118 [03:29<10:31,  7.02s/it, loss=4.1523, lr=1.86e-05, step=70414]
# Epoch 36/50:  24%|██▎       | 28/118 [03:34<10:31,  7.02s/it, loss=4.1820, lr=1.86e-05, step=70414]
# Epoch 36/50:  25%|██▍       | 29/118 [03:34<09:30,  6.41s/it, loss=4.1820, lr=1.86e-05, step=70414]
# Epoch 36/50:  25%|██▍       | 29/118 [03:48<09:30,  6.41s/it, loss=4.1794, lr=1.86e-05, step=70415]
# Epoch 36/50:  25%|██▌       | 30/118 [03:48<12:29,  8.52s/it, loss=4.1794, lr=1.86e-05, step=70415]
# Epoch 36/50:  25%|██▌       | 30/118 [03:56<12:29,  8.52s/it, loss=4.1730, lr=1.86e-05, step=70415]
# Epoch 36/50:  26%|██▋       | 31/118 [03:56<12:14,  8.44s/it, loss=4.1730, lr=1.86e-05, step=70415]
# Epoch 36/50:  26%|██▋       | 31/118 [04:08<12:14,  8.44s/it, loss=4.1560, lr=1.86e-05, step=70416]
# Epoch 36/50:  27%|██▋       | 32/118 [04:08<13:26,  9.37s/it, loss=4.1560, lr=1.86e-05, step=70416]
# Epoch 36/50:  27%|██▋       | 32/118 [04:17<13:26,  9.37s/it, loss=4.1566, lr=1.86e-05, step=70416]
# Epoch 36/50:  28%|██▊       | 33/118 [04:17<13:18,  9.39s/it, loss=4.1566, lr=1.86e-05, step=70416]
# Epoch 36/50:  28%|██▊       | 33/118 [04:24<13:18,  9.39s/it, loss=4.1995, lr=1.86e-05, step=70417]
# Epoch 36/50:  29%|██▉       | 34/118 [04:24<12:21,  8.82s/it, loss=4.1995, lr=1.86e-05, step=70417]
# Epoch 36/50:  29%|██▉       | 34/118 [04:33<12:21,  8.82s/it, loss=4.1698, lr=1.86e-05, step=70417]
# Epoch 36/50:  30%|██▉       | 35/118 [04:33<11:58,  8.66s/it, loss=4.1698, lr=1.86e-05, step=70417]
# Epoch 36/50:  30%|██▉       | 35/118 [04:57<11:58,  8.66s/it, loss=4.1891, lr=1.86e-05, step=70418]
# Epoch 36/50:  31%|███       | 36/118 [04:57<18:06, 13.25s/it, loss=4.1891, lr=1.86e-05, step=70418]
# Epoch 36/50:  31%|███       | 36/118 [05:03<18:06, 13.25s/it, loss=4.1958, lr=1.86e-05, step=70418]
# Epoch 36/50:  31%|███▏      | 37/118 [05:03<15:03, 11.15s/it, loss=4.1958, lr=1.86e-05, step=70418]
# Epoch 36/50:  31%|███▏      | 37/118 [05:06<15:03, 11.15s/it, loss=4.1870, lr=1.86e-05, step=70419]
# Epoch 36/50:  32%|███▏      | 38/118 [05:06<11:29,  8.62s/it, loss=4.1870, lr=1.86e-05, step=70419]
# Epoch 36/50:  32%|███▏      | 38/118 [05:08<11:29,  8.62s/it, loss=4.1674, lr=1.86e-05, step=70419]
# Epoch 36/50:  33%|███▎      | 39/118 [05:08<08:55,  6.78s/it, loss=4.1674, lr=1.86e-05, step=70419]
# Epoch 36/50:  33%|███▎      | 39/118 [05:11<08:55,  6.78s/it, loss=4.0052, lr=1.86e-05, step=70420]
# Epoch 36/50:  34%|███▍      | 40/118 [05:11<07:05,  5.45s/it, loss=4.0052, lr=1.86e-05, step=70420]
# Epoch 36/50:  34%|███▍      | 40/118 [05:13<07:05,  5.45s/it, loss=4.1782, lr=1.86e-05, step=70420]
# Epoch 36/50:  35%|███▍      | 41/118 [05:13<05:50,  4.55s/it, loss=4.1782, lr=1.86e-05, step=70420]
# Epoch 36/50:  35%|███▍      | 41/118 [05:16<05:50,  4.55s/it, loss=4.1622, lr=1.86e-05, step=70421]
# Epoch 36/50:  36%|███▌      | 42/118 [05:16<04:59,  3.95s/it, loss=4.1622, lr=1.86e-05, step=70421]
# Epoch 36/50:  36%|███▌      | 42/118 [05:18<04:59,  3.95s/it, loss=4.1738, lr=1.86e-05, step=70421]
# Epoch 36/50:  36%|███▋      | 43/118 [05:18<04:30,  3.61s/it, loss=4.1738, lr=1.86e-05, step=70421]
# Epoch 36/50:  36%|███▋      | 43/118 [05:21<04:30,  3.61s/it, loss=4.1757, lr=1.86e-05, step=70422]
# Epoch 36/50:  37%|███▋      | 44/118 [05:21<04:01,  3.26s/it, loss=4.1757, lr=1.86e-05, step=70422]
# Epoch 36/50:  37%|███▋      | 44/118 [05:23<04:01,  3.26s/it, loss=4.1569, lr=1.86e-05, step=70422]
# Epoch 36/50:  38%|███▊      | 45/118 [05:23<03:44,  3.08s/it, loss=4.1569, lr=1.86e-05, step=70422]
# Epoch 36/50:  38%|███▊      | 45/118 [05:26<03:44,  3.08s/it, loss=4.1964, lr=1.86e-05, step=70423]
# Epoch 36/50:  39%|███▉      | 46/118 [05:26<03:22,  2.82s/it, loss=4.1964, lr=1.86e-05, step=70423]
# Epoch 36/50:  39%|███▉      | 46/118 [05:29<03:22,  2.82s/it, loss=4.1794, lr=1.86e-05, step=70423]
# Epoch 36/50:  40%|███▉      | 47/118 [05:29<03:23,  2.86s/it, loss=4.1794, lr=1.86e-05, step=70423]
# Epoch 36/50:  40%|███▉      | 47/118 [05:31<03:23,  2.86s/it, loss=4.1847, lr=1.86e-05, step=70424]
# Epoch 36/50:  41%|████      | 48/118 [05:31<03:16,  2.80s/it, loss=4.1847, lr=1.86e-05, step=70424]
# Epoch 36/50:  41%|████      | 48/118 [05:34<03:16,  2.80s/it, loss=4.0040, lr=1.86e-05, step=70424]
# Epoch 36/50:  42%|████▏     | 49/118 [05:34<03:02,  2.64s/it, loss=4.0040, lr=1.86e-05, step=70424]
# Epoch 36/50:  42%|████▏     | 49/118 [05:36<03:02,  2.64s/it, loss=4.1884, lr=1.86e-05, step=70425]
# Epoch 36/50:  42%|████▏     | 50/118 [05:36<02:58,  2.62s/it, loss=4.1884, lr=1.86e-05, step=70425]
# Epoch 36/50:  42%|████▏     | 50/118 [05:38<02:58,  2.62s/it, loss=4.1727, lr=1.86e-05, step=70425]
# Epoch 36/50:  43%|████▎     | 51/118 [05:38<02:50,  2.54s/it, loss=4.1727, lr=1.86e-05, step=70425]
# Epoch 36/50:  43%|████▎     | 51/118 [05:41<02:50,  2.54s/it, loss=4.1971, lr=1.86e-05, step=70426]
# Epoch 36/50:  44%|████▍     | 52/118 [05:41<02:43,  2.47s/it, loss=4.1971, lr=1.86e-05, step=70426]
# Epoch 36/50:  44%|████▍     | 52/118 [05:43<02:43,  2.47s/it, loss=4.1689, lr=1.86e-05, step=70426]
# Epoch 36/50:  45%|████▍     | 53/118 [05:43<02:38,  2.45s/it, loss=4.1689, lr=1.86e-05, step=70426]
# Epoch 36/50:  45%|████▍     | 53/118 [05:46<02:38,  2.45s/it, loss=4.1785, lr=1.86e-05, step=70427]
# Epoch 36/50:  46%|████▌     | 54/118 [05:46<02:36,  2.44s/it, loss=4.1785, lr=1.86e-05, step=70427]
# Epoch 36/50:  46%|████▌     | 54/118 [05:48<02:36,  2.44s/it, loss=4.1813, lr=1.86e-05, step=70427]
# Epoch 36/50:  47%|████▋     | 55/118 [05:48<02:35,  2.48s/it, loss=4.1813, lr=1.86e-05, step=70427]
# Epoch 36/50:  47%|████▋     | 55/118 [05:51<02:35,  2.48s/it, loss=4.1792, lr=1.86e-05, step=70428]
# Epoch 36/50:  47%|████▋     | 56/118 [05:51<02:34,  2.50s/it, loss=4.1792, lr=1.86e-05, step=70428]
# Epoch 36/50:  47%|████▋     | 56/118 [05:53<02:34,  2.50s/it, loss=4.0385, lr=1.86e-05, step=70428]
# Epoch 36/50:  48%|████▊     | 57/118 [05:53<02:28,  2.44s/it, loss=4.0385, lr=1.86e-05, step=70428]
# Epoch 36/50:  48%|████▊     | 57/118 [05:55<02:28,  2.44s/it, loss=4.1560, lr=1.86e-05, step=70429]
# Epoch 36/50:  49%|████▉     | 58/118 [05:55<02:25,  2.43s/it, loss=4.1560, lr=1.86e-05, step=70429]
# Epoch 36/50:  49%|████▉     | 58/118 [05:58<02:25,  2.43s/it, loss=4.1543, lr=1.86e-05, step=70429]
# Epoch 36/50:  50%|█████     | 59/118 [05:58<02:25,  2.46s/it, loss=4.1543, lr=1.86e-05, step=70429]
# Epoch 36/50:  50%|█████     | 59/118 [06:00<02:25,  2.46s/it, loss=4.1946, lr=1.86e-05, step=70430]
# Epoch 36/50:  51%|█████     | 60/118 [06:00<02:22,  2.45s/it, loss=4.1946, lr=1.86e-05, step=70430]
# Epoch 36/50:  51%|█████     | 60/118 [06:03<02:22,  2.45s/it, loss=4.1945, lr=1.86e-05, step=70430]
# Epoch 36/50:  52%|█████▏    | 61/118 [06:03<02:19,  2.44s/it, loss=4.1945, lr=1.86e-05, step=70430]
# Epoch 36/50:  52%|█████▏    | 61/118 [06:05<02:19,  2.44s/it, loss=4.1881, lr=1.86e-05, step=70431]
# Epoch 36/50:  53%|█████▎    | 62/118 [06:05<02:17,  2.45s/it, loss=4.1881, lr=1.86e-05, step=70431]
# Epoch 36/50:  53%|█████▎    | 62/118 [06:08<02:17,  2.45s/it, loss=4.2175, lr=1.86e-05, step=70431]
# Epoch 36/50:  53%|█████▎    | 63/118 [06:08<02:12,  2.41s/it, loss=4.2175, lr=1.86e-05, step=70431]
# Epoch 36/50:  53%|█████▎    | 63/118 [06:10<02:12,  2.41s/it, loss=4.1619, lr=1.86e-05, step=70432]
# Epoch 36/50:  54%|█████▍    | 64/118 [06:10<02:10,  2.42s/it, loss=4.1619, lr=1.86e-05, step=70432]
# Epoch 36/50:  54%|█████▍    | 64/118 [06:13<02:10,  2.42s/it, loss=4.1635, lr=1.86e-05, step=70432]
# Epoch 36/50:  55%|█████▌    | 65/118 [06:13<02:16,  2.58s/it, loss=4.1635, lr=1.86e-05, step=70432]
# Epoch 36/50:  55%|█████▌    | 65/118 [06:16<02:16,  2.58s/it, loss=4.1752, lr=1.86e-05, step=70433]
# Epoch 36/50:  56%|█████▌    | 66/118 [06:16<02:13,  2.57s/it, loss=4.1752, lr=1.86e-05, step=70433]
# Epoch 36/50:  56%|█████▌    | 66/118 [06:18<02:13,  2.57s/it, loss=3.9786, lr=1.86e-05, step=70433]
# Epoch 36/50:  57%|█████▋    | 67/118 [06:18<02:09,  2.54s/it, loss=3.9786, lr=1.86e-05, step=70433]
# Epoch 36/50:  57%|█████▋    | 67/118 [06:20<02:09,  2.54s/it, loss=4.1719, lr=1.86e-05, step=70434]
# Epoch 36/50:  58%|█████▊    | 68/118 [06:20<01:51,  2.24s/it, loss=4.1719, lr=1.86e-05, step=70434][rank1]:[E607 02:01:08.839380980 ProcessGroupNCCL.cpp:616] [Rank 1] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=208, OpType=ALLREDUCE, NumelIn=2, NumelOut=2, Timeout(ms)=1800000) ran for 1800082 milliseconds before timing out.
# [rank1]:[E607 02:01:08.841166388 ProcessGroupNCCL.cpp:1785] [PG ID 0 PG GUID 0(default_pg) Rank 1] Exception (either an error or timeout) detected by watchdog at work: 208, last enqueued NCCL work: 208, last completed NCCL work: 207.
# [rank1]:[E607 02:01:09.635592900 ProcessGroupNCCL.cpp:1834] [PG ID 0 PG GUID 0(default_pg) Rank 1] Timeout at NCCL work: 208, last enqueued NCCL work: 208, last completed NCCL work: 207.
# [rank1]:[E607 02:01:09.635647852 ProcessGroupNCCL.cpp:630] [Rank 1] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank1]:[E607 02:01:09.635661362 ProcessGroupNCCL.cpp:636] [Rank 1] To avoid data inconsistency, we are taking the entire process down.
# [rank1]:[E607 02:01:09.640628093 ProcessGroupNCCL.cpp:1595] [PG ID 0 PG GUID 0(default_pg) Rank 1] Process group watchdog thread terminated with exception: [Rank 1] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=208, OpType=ALLREDUCE, NumelIn=2, NumelOut=2, Timeout(ms)=1800000) ran for 1800082 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7fd553aa2446 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7fd554db5772 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7fd554dbcbb3 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7fd554dbe61d in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7fd59d74b5c0 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x7ea5 (0x7fd5aa084ea5 in /lib64/libpthread.so.0)
# frame #6: clone + 0x6d (0x7fd5a96a496d in /lib64/libc.so.6)
#
# terminate called after throwing an instance of 'c10::DistBackendError'
# what():  [PG ID 0 PG GUID 0(default_pg) Rank 1] Process group watchdog thread terminated with exception: [Rank 1] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=208, OpType=ALLREDUCE, NumelIn=2, NumelOut=2, Timeout(ms)=1800000) ran for 1800082 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7fd553aa2446 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7fd554db5772 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7fd554dbcbb3 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7fd554dbe61d in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7fd59d74b5c0 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x7ea5 (0x7fd5aa084ea5 in /lib64/libpthread.so.0)
# frame #6: clone + 0x6d (0x7fd5a96a496d in /lib64/libc.so.6)
#
# Exception raised from ncclCommWatchdog at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:1601 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7fd553aa2446 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe4271b (0x7fd554a2b71b in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x145c0 (0x7fd59d74b5c0 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch.so)
# frame #3: <unknown function> + 0x7ea5 (0x7fd5aa084ea5 in /lib64/libpthread.so.0)
# frame #4: clone + 0x6d (0x7fd5a96a496d in /lib64/libc.so.6)
#
# [rank0]:[E607 02:01:10.266995743 ProcessGroupNCCL.cpp:616] [Rank 0] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=208, OpType=ALLREDUCE, NumelIn=3046656, NumelOut=3046656, Timeout(ms)=1800000) ran for 1800091 milliseconds before timing out.
# [rank0]:[E607 02:01:10.268290538 ProcessGroupNCCL.cpp:1785] [PG ID 0 PG GUID 0(default_pg) Rank 0] Exception (either an error or timeout) detected by watchdog at work: 208, last enqueued NCCL work: 210, last completed NCCL work: 207.
# [rank0]:[E607 02:01:16.303420148 ProcessGroupNCCL.cpp:1834] [PG ID 0 PG GUID 0(default_pg) Rank 0] Timeout at NCCL work: 208, last enqueued NCCL work: 210, last completed NCCL work: 207.
# [rank0]:[E607 02:01:16.303448388 ProcessGroupNCCL.cpp:630] [Rank 0] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank0]:[E607 02:01:16.303457312 ProcessGroupNCCL.cpp:636] [Rank 0] To avoid data inconsistency, we are taking the entire process down.
# [rank0]:[E607 02:01:16.305021648 ProcessGroupNCCL.cpp:1595] [PG ID 0 PG GUID 0(default_pg) Rank 0] Process group watchdog thread terminated with exception: [Rank 0] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=208, OpType=ALLREDUCE, NumelIn=3046656, NumelOut=3046656, Timeout(ms)=1800000) ran for 1800091 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f9f9f027446 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7f9fa033a772 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7f9fa0341bb3 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7f9fa034361d in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7f9fe8cd05c0 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x7ea5 (0x7f9ff5609ea5 in /lib64/libpthread.so.0)
# frame #6: clone + 0x6d (0x7f9ff4c2996d in /lib64/libc.so.6)
#
# terminate called after throwing an instance of 'c10::DistBackendError'
# what():  [PG ID 0 PG GUID 0(default_pg) Rank 0] Process group watchdog thread terminated with exception: [Rank 0] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=208, OpType=ALLREDUCE, NumelIn=3046656, NumelOut=3046656, Timeout(ms)=1800000) ran for 1800091 milliseconds before timing out.
# Exception raised from checkTimeout at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:618 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f9f9f027446 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libc10.so)
# frame #1: c10d::ProcessGroupNCCL::WorkNCCL::checkTimeout(std::optional<std::chrono::duration<long, std::ratio<1l, 1000l> > >) + 0x282 (0x7f9fa033a772 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: c10d::ProcessGroupNCCL::watchdogHandler() + 0x233 (0x7f9fa0341bb3 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #3: c10d::ProcessGroupNCCL::ncclCommWatchdog() + 0x14d (0x7f9fa034361d in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x145c0 (0x7f9fe8cd05c0 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch.so)
# frame #5: <unknown function> + 0x7ea5 (0x7f9ff5609ea5 in /lib64/libpthread.so.0)
# frame #6: clone + 0x6d (0x7f9ff4c2996d in /lib64/libc.so.6)
#
# Exception raised from ncclCommWatchdog at ../torch/csrc/distributed/c10d/ProcessGroupNCCL.cpp:1601 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x96 (0x7f9f9f027446 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe4271b (0x7f9f9ffb071b in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x145c0 (0x7f9fe8cd05c0 in /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/lib/libtorch.so)
# frame #3: <unknown function> + 0x7ea5 (0x7f9ff5609ea5 in /lib64/libpthread.so.0)
# frame #4: clone + 0x6d (0x7f9ff4c2996d in /lib64/libc.so.6)
#
# W0607 02:01:19.137000 24522 micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 24646 closing signal SIGTERM
# E0607 02:01:34.183000 24522 micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/elastic/multiprocessing/api.py:869] failed (exitcode: -6) local_rank: 0 (pid: 24645) of binary: /public/home/jijh/micromamba/envs/gpu_env/bin/python
# Traceback (most recent call last):
# File "<frozen runpy>", line 198, in _run_module_as_main
# File "<frozen runpy>", line 88, in _run_code
# File "/public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/run.py", line 923, in <module>
# main()
# File "/public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/elastic/multiprocessing/errors/__init__.py", line 355, in wrapper
# return f(*args, **kwargs)
# ^^^^^^^^^^^^^^^^^^
# File "/public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/run.py", line 919, in main
# run(args)
# File "/public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/run.py", line 910, in run
# elastic_launch(
# File "/public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/launcher/api.py", line 138, in __call__
# return launch_agent(self._config, self._entrypoint, list(args))
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# File "/public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/distributed/launcher/api.py", line 269, in launch_agent
# raise ChildFailedError(
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# /home1/jijh/diffusion_project/ADiffusion/src/pipeline/train_clip_graph_gigapath_ddp.py FAILED
# ------------------------------------------------------------
# Failures:
# <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
# time      : 2025-06-07_02:01:19
# host      : gpucw1
# rank      : 0 (local_rank: 0)
# exitcode  : -6 (pid: 24645)
# error_file: <N/A>
# traceback : Signal 6 (SIGABRT) received by PID 24645
# ============================================================
# ------------------------------
# --- CLIP Script Finished ---
# CLIP Training script exited with error code 1.
