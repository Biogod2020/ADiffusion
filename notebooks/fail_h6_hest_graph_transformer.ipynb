# %% [markdown]
# # Graph-Conditioned Diffusion Model Fine-tuning (Spatial Transcriptomics) - Precomputed Graphs

# %% [markdown]
# ## Cell 1: Imports (Unchanged)

# %%
import os
import random
import glob
import datetime
import time
import sys
import subprocess
import shlex
import pickle
working_dir = os.path.dirname("/home1/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_transformer.ipynb")
os.chdir(working_dir)
# Set the working directory to the script's directory
# This is necessary to ensure that relative imports work correctly
# and that the script can find the required files.
import torch
import numpy as np
import matplotlib.pyplot as plt
try:
    from tqdm.notebook import tqdm as notebook_tqdm
    IS_NOTEBOOK = True
    print("Notebook environment detected.")
except ImportError:
    from tqdm.auto import tqdm as notebook_tqdm
    IS_NOTEBOOK = False
    print("Using standard tqdm.")

# Assume helper files are in the same directory or accessible via sys.path
# Important: We now use SpatialGraphDataset which loads precomputed data
try:
    from dataset import SpatialGraphDataset
    from models import FullModel
    from graph_utils import get_sinusoidal_positional_encoding # Still needed by precompute script
    print("Helper modules imported successfully.")
except ImportError as e:
     print(f"ERROR importing helper modules: {e}. Make sure .py files are in the correct location.")
     # Stop notebook execution if helpers missing
     raise e

# %matplotlib inline
# Out:
# Notebook environment detected.
# Helper modules imported successfully.

# %% [markdown]
# ## Cell 2: Configuration Class

# %%
class TrainingConfig:
    # --- Sample Filtering ---
    ALLOWED_SAMPLE_IDS = [
        'TENX159', 'TENX138', 'TENX131', 'TENX88', 'TENX87', 'TENX86', 'TENX85', 'TENX84', 'TENX83', 'TENX82',
        'TENX80', 'TENX79', 'TENX78', 'TENX77', 'TENX73', 'TENX69', 'TENX67', 'TENX61', 'TENX60', 'TENX58',
        'TENX56', 'TENX55', 'TENX54', 'TENX52', 'TENX43', 'TENX31', 'TENX30', 'TENX27', 'TENX19', 'TENX18',
        'ZEN61', 'ZEN60', 'SPA15', 'SPA14', 'SPA13', 'SPA12', 'SPA11', 'SPA10', 'SPA9', 'SPA8', 'SPA7', 'SPA6',
        'SPA5', 'SPA4', 'MEND131', 'MEND130', 'MEND129', 'MEND124', 'MEND123', 'MEND78', 'MEND77', 'MEND76',
        'MEND75', 'MEND74', 'MEND73', 'MEND72', 'MEND71', 'MEND68', 'MEND67', 'MEND66', 'MEND65', 'MEND64',
        'MEND63', 'MEND55', 'MEND53', 'MEND50', 'MEND46', 'MEND44', 'MEND43', 'MEND42', 'NCBI809', 'NCBI808',
        'NCBI807', 'NCBI806', 'NCBI802', 'NCBI801', 'NCBI800', 'NCBI799', 'NCBI720', 'NCBI719', 'NCBI718',
        'NCBI717', 'NCBI716', 'NCBI715', 'NCBI671', 'NCBI670', 'NCBI669', 'NCBI668', 'NCBI667', 'NCBI666',
        'NCBI665', 'NCBI664', 'NCBI663', 'NCBI662', 'NCBI661', 'NCBI660', 'NCBI659', 'NCBI658', 'NCBI657',
        'NCBI656', 'NCBI655', 'NCBI654', 'NCBI653', 'NCBI641', 'NCBI640', 'NCBI639', 'NCBI638', 'NCBI637',
        'NCBI636', 'NCBI635', 'NCBI634', 'NCBI633', 'NCBI632', 'NCBI631', 'NCBI630', 'NCBI629', 'NCBI628',
        'NCBI533', 'NCBI532', 'NCBI531', 'NCBI530', 'NCBI529', 'NCBI528', 'NCBI527', 'NCBI410', 'NCBI409',
        'NCBI408', 'NCBI407', 'NCBI406', 'NCBI405', 'NCBI404', 'NCBI403', 'NCBI402', 'NCBI401', 'NCBI400',
        'NCBI399', 'NCBI398', 'NCBI397', 'NCBI396', 'NCBI395', 'NCBI394', 'NCBI393', 'NCBI392', 'NCBI391',
        'NCBI390', 'NCBI389', 'NCBI388', 'NCBI387', 'NCBI386', 'NCBI385', 'NCBI384', 'NCBI383', 'NCBI382',
        'NCBI381', 'NCBI380', 'NCBI379', 'NCBI378', 'NCBI377', 'NCBI376', 'NCBI375', 'NCBI374', 'NCBI373',
        'NCBI372', 'NCBI371', 'NCBI370', 'NCBI369', 'NCBI368', 'NCBI367', 'NCBI366', 'NCBI365', 'NCBI364',
        'NCBI363', 'NCBI362', 'NCBI361', 'NCBI360', 'NCBI359', 'NCBI358', 'NCBI357', 'NCBI356', 'NCBI355',
        'NCBI354', 'NCBI353', 'NCBI352', 'NCBI351', 'NCBI350', 'NCBI349', 'NCBI348', 'NCBI347', 'NCBI346',
        'NCBI345', 'NCBI344', 'NCBI343', 'NCBI342', 'NCBI341', 'NCBI340', 'NCBI339', 'NCBI338', 'NCBI337',
        'NCBI336', 'MISC12', 'MISC11', 'MISC10', 'MISC9', 'MISC8', 'MISC7', 'MISC6', 'MISC5', 'MISC4', 'MISC3',
        'MISC2', 'MISC1'
    ] # Set to None or [] to process all

    # --- Hardware & Precision ---
    GPU_IDS = [0, 1, 2] #<-- CHANGE IF NEEDED
    PRIMARY_GPU_ID = GPU_IDS[0] if GPU_IDS else 0
    NUM_GPUS = len(GPU_IDS) if torch.cuda.is_available() and GPU_IDS else 0
    PRIMARY_DEVICE_NAME = f"cuda:{PRIMARY_GPU_ID}" if NUM_GPUS > 0 else "cpu"
    MIXED_PRECISION_TYPE = "bf16"
    DDP_MASTER_PORT = 29504 # Yet another port

    # --- Data Paths ---
    latent_dir = "/cwStorage/nodecw_group/jijh/hest_output_latents_bf16"
    expr_base_dir = "/cwStorage/nodecw_group/jijh/hest_output"
    # Modify output paths if filtering is applied
    _filter_suffix = "_filtered" if ALLOWED_SAMPLE_IDS else ""
    graph_data_dir = f"/cwStorage/nodecw_group/jijh/hest_graph_data{_filter_suffix}"
    valid_spots_path = os.path.join(graph_data_dir, f"valid_spots_flat{_filter_suffix}.pkl")

    # Output / Model paths
    checkpoint_dir = "/cwStorage/nodecw_group/jijh/model_path/"
    log_dir = f"/cwStorage/nodecw_group/jijh/training_log/logs_graph_diffusion_precomp{_filter_suffix}"
    final_model_save_path = os.path.join(checkpoint_dir, f"graph_unet_precomp{_filter_suffix}_final.pt")

    # --- Preprocessing Parameters ---
    num_raw_genes = None
    pca_target_dim = 50
    normalization_scale_factor = 1e4
    pos_encoding_dim = 128
    graph_k_neighbors = 8
    preprocessing_n_jobs = 8
    force_rebuild_graphs = False

    # --- Model Parameters ---
    vae_model_path = "/cwStorage/nodecw_group/jijh/model_path/finetuned_taesd_v21_notebook_apr2.pt"
    vae_sd_version = 'v2.1'
    unet_sample_size = 64
    unet_in_channels = 4
    unet_out_channels = 4
    unet_block_out_channels = (320, 640, 1280, 1280)
    unet_down_block_types = ('CrossAttnDownBlock2D', 'CrossAttnDownBlock2D', 'CrossAttnDownBlock2D', 'DownBlock2D')
    unet_up_block_types = ('UpBlock2D', 'CrossAttnUpBlock2D', 'CrossAttnUpBlock2D', 'CrossAttnUpBlock2D')
    unet_cross_attention_dim = 768
    pretrained_unet_checkpoint_path = "/cwStorage/nodecw_group/jijh/model_path/unet_ddp_bf16_ep15_bs32x3_lr0.0001_acc4.pt"
    graph_transformer_hidden_dim = 768
    graph_transformer_dim = 768
    graph_transformer_layers = 6
    graph_transformer_heads = 8

    # --- Fine-tuning Parameters ---
    batch_size_per_gpu = 16
    epochs = 20
    lr_unet = 1e-5
    lr_graph = 1e-4
    optimizer_type = "AdamW"
    accumulation_steps = 4
    scheduler_train_timesteps = 1000

    # --- Logging & Saving ---
    num_workers = 16
    checkpoint_filename_prefix = f"graph_unet_precomp{_filter_suffix}_ddp"
    log_interval = 20
    sample_interval = 1
    save_interval = 1
    sampling_inference_steps = 30
    sampling_batch_size = 8

    # --- Script Paths ---
    preprocess_script_path = "preprocess_graphs.py"
    train_script_path = "train_graph_diffusion_ddp.py"

    @classmethod
    def get_preprocess_cmd(cls):
        """Generates the command to run the preprocessing script."""
        if not os.path.exists(cls.preprocess_script_path): return None
        cmd = [
            sys.executable, cls.preprocess_script_path,
            f"--latent_dir={cls.latent_dir}", f"--expr_base_dir={cls.expr_base_dir}",
            f"--output_graph_dir={cls.graph_data_dir}", f"--valid_spots_output_path={cls.valid_spots_path}",
            f"--num_raw_genes={cls.num_raw_genes}" if cls.num_raw_genes is not None else "--num_raw_genes=-1",
            f"--pca_target_dim={cls.pca_target_dim}", f"--normalization_scale_factor={cls.normalization_scale_factor}",
            f"--pos_encoding_dim={cls.pos_encoding_dim}", f"--graph_k_neighbors={cls.graph_k_neighbors}",
            f"--n_jobs={cls.preprocessing_n_jobs}",
        ]
        if cls.force_rebuild_graphs: cmd.append("--force_rebuild")
        if cls.ALLOWED_SAMPLE_IDS: cmd.append(f"--allowed_ids={','.join(cls.ALLOWED_SAMPLE_IDS)}")
        return cmd

    @classmethod
    def get_train_script_args(cls):
        """Generates CLI arguments for the DDP training script."""
        args = [
            f"--graph_data_dir={cls.graph_data_dir}", f"--valid_spots_path={cls.valid_spots_path}",
            f"--latent_dir={cls.latent_dir}", f"--checkpoint_dir={cls.checkpoint_dir}", f"--log_dir={cls.log_dir}",
            f"--pretrained_unet_checkpoint_path={cls.pretrained_unet_checkpoint_path}",
            f"--vae_model_path={cls.vae_model_path}", f"--vae_sd_version={cls.vae_sd_version}",
            f"--pca_target_dim={cls.pca_target_dim}", f"--pos_encoding_dim={cls.pos_encoding_dim}",
            f"--unet_sample_size={cls.unet_sample_size}", f"--unet_in_channels={cls.unet_in_channels}",
            f"--unet_out_channels={cls.unet_out_channels}",
            f"--unet_block_out_channels={','.join(map(str, cls.unet_block_out_channels))}",
            f"--unet_down_block_types={','.join(cls.unet_down_block_types)}",
            f"--unet_up_block_types={','.join(cls.unet_up_block_types)}",
            f"--unet_cross_attention_dim={cls.unet_cross_attention_dim}",
            f"--graph_transformer_hidden_dim={cls.graph_transformer_hidden_dim}",
            f"--graph_transformer_dim={cls.graph_transformer_dim}",
            f"--graph_transformer_layers={cls.graph_transformer_layers}",
            f"--graph_transformer_heads={cls.graph_transformer_heads}",
            f"--epochs={cls.epochs}", f"--batch_size_per_gpu={cls.batch_size_per_gpu}",
            f"--lr_unet={cls.lr_unet}", f"--lr_graph={cls.lr_graph}", f"--optimizer_type={cls.optimizer_type}",
            f"--accumulation_steps={cls.accumulation_steps}", f"--mixed_precision={cls.MIXED_PRECISION_TYPE}",
            f"--scheduler_train_timesteps={cls.scheduler_train_timesteps}",
            f"--num_workers={cls.num_workers}", f"--checkpoint_filename_prefix={cls.checkpoint_filename_prefix}",
            f"--log_interval={cls.log_interval}", f"--sample_interval={cls.sample_interval}",
            f"--save_interval={cls.save_interval}", f"--sampling_inference_steps={cls.sampling_inference_steps}",
            f"--sampling_batch_size={cls.sampling_batch_size}",
        ]
        return args

# %% Cell 3: Instantiate Config
config = TrainingConfig()
# Make sure output directories exist before running scripts
os.makedirs(config.graph_data_dir, exist_ok=True)
os.makedirs(config.checkpoint_dir, exist_ok=True)
os.makedirs(config.log_dir, exist_ok=True)

# %% [markdown]
# ## Cell 4: Run Preprocessing Script

# %%
print("--- Running Preprocessing Script ---")
preprocess_cmd = config.get_preprocess_cmd()

if preprocess_cmd:
    run_preprocessing = config.force_rebuild_graphs or not os.path.exists(config.valid_spots_path)
    if run_preprocessing:
        print("Executing command:")
        print(shlex.join(preprocess_cmd))
        print("-" * 30)
        start_time = time.time()
        result = subprocess.run(preprocess_cmd, capture_output=True, text=True, encoding='utf-8', errors='replace')
        end_time = time.time()
        print(f"Preprocessing script finished in {end_time - start_time:.2f} seconds.")
        print("--- Preprocessing Script STDOUT ---")
        print(result.stdout)
        print("--- Preprocessing Script STDERR ---")
        print(result.stderr)
        if result.returncode != 0:
            print(f"ERROR: Preprocessing script failed with exit code {result.returncode}.")
            raise RuntimeError("Preprocessing script failed.")
        else:
            print("Preprocessing script completed successfully.")
            if not os.path.exists(config.valid_spots_path):
                 raise FileNotFoundError(f"Preprocessing script finished but valid spots file is missing: {config.valid_spots_path}")
            if not glob.glob(os.path.join(config.graph_data_dir, "*.pt")): # Check for graph files too
                 raise FileNotFoundError(f"Preprocessing script finished but no graph files found in: {config.graph_data_dir}")
    else:
        print(f"Skipping preprocessing. Required output file '{config.valid_spots_path}' already exists.")
        print(f"Set config.force_rebuild_graphs = True to re-run.")
else:
    print(f"Error: Preprocessing script '{config.preprocess_script_path}' not found.")
    raise FileNotFoundError("Preprocessing script not found.")
# Out:
# --- Running Preprocessing Script ---
# Executing command:
# /public/home/jijh/micromamba/envs/gpu_env/bin/python preprocess_graphs.py --latent_dir=/cwStorage/nodecw_group/jijh/hest_output_latents_bf16 --expr_base_dir=/cwStorage/nodecw_group/jijh/hest_output --output_graph_dir=/cwStorage/nodecw_group/jijh/hest_graph_data_filtered --valid_spots_output_path=/cwStorage/nodecw_group/jijh/hest_graph_data_filtered/valid_spots_flat_filtered.pkl --num_raw_genes=-1 --pca_target_dim=50 --normalization_scale_factor=10000.0 --pos_encoding_dim=128 --graph_k_neighbors=8 --n_jobs=8 --allowed_ids=TENX159,TENX138,TENX131,TENX88,TENX87,TENX86,TENX85,TENX84,TENX83,TENX82,TENX80,TENX79,TENX78,TENX77,TENX73,TENX69,TENX67,TENX61,TENX60,TENX58,TENX56,TENX55,TENX54,TENX52,TENX43,TENX31,TENX30,TENX27,TENX19,TENX18,ZEN61,ZEN60,SPA15,SPA14,SPA13,SPA12,SPA11,SPA10,SPA9,SPA8,SPA7,SPA6,SPA5,SPA4,MEND131,MEND130,MEND129,MEND124,MEND123,MEND78,MEND77,MEND76,MEND75,MEND74,MEND73,MEND72,MEND71,MEND68,MEND67,MEND66,MEND65,MEND64,MEND63,MEND55,MEND53,MEND50,MEND46,MEND44,MEND43,MEND42,NCBI809,NCBI808,NCBI807,NCBI806,NCBI802,NCBI801,NCBI800,NCBI799,NCBI720,NCBI719,NCBI718,NCBI717,NCBI716,NCBI715,NCBI671,NCBI670,NCBI669,NCBI668,NCBI667,NCBI666,NCBI665,NCBI664,NCBI663,NCBI662,NCBI661,NCBI660,NCBI659,NCBI658,NCBI657,NCBI656,NCBI655,NCBI654,NCBI653,NCBI641,NCBI640,NCBI639,NCBI638,NCBI637,NCBI636,NCBI635,NCBI634,NCBI633,NCBI632,NCBI631,NCBI630,NCBI629,NCBI628,NCBI533,NCBI532,NCBI531,NCBI530,NCBI529,NCBI528,NCBI527,NCBI410,NCBI409,NCBI408,NCBI407,NCBI406,NCBI405,NCBI404,NCBI403,NCBI402,NCBI401,NCBI400,NCBI399,NCBI398,NCBI397,NCBI396,NCBI395,NCBI394,NCBI393,NCBI392,NCBI391,NCBI390,NCBI389,NCBI388,NCBI387,NCBI386,NCBI385,NCBI384,NCBI383,NCBI382,NCBI381,NCBI380,NCBI379,NCBI378,NCBI377,NCBI376,NCBI375,NCBI374,NCBI373,NCBI372,NCBI371,NCBI370,NCBI369,NCBI368,NCBI367,NCBI366,NCBI365,NCBI364,NCBI363,NCBI362,NCBI361,NCBI360,NCBI359,NCBI358,NCBI357,NCBI356,NCBI355,NCBI354,NCBI353,NCBI352,NCBI351,NCBI350,NCBI349,NCBI348,NCBI347,NCBI346,NCBI345,NCBI344,NCBI343,NCBI342,NCBI341,NCBI340,NCBI339,NCBI338,NCBI337,NCBI336,MISC12,MISC11,MISC10,MISC9,MISC8,MISC7,MISC6,MISC5,MISC4,MISC3,MISC2,MISC1
# ------------------------------
# Preprocessing script finished in 150.58 seconds.
# --- Preprocessing Script STDOUT ---
# Processing only specified sample IDs: {'TENX78', 'SPA9', 'TENX85', 'NCBI388', 'NCBI399', 'SPA4', 'NCBI410', 'NCBI389', 'MEND67', 'NCBI339', 'NCBI807', 'TENX54', 'NCBI382', 'NCBI656', 'MISC4', 'NCBI373', 'NCBI801', 'NCBI378', 'TENX138', 'NCBI338', 'MEND53', 'SPA11', 'NCBI719', 'NCBI375', 'TENX58', 'MEND65', 'TENX55', 'NCBI377', 'TENX69', 'MEND75', 'NCBI392', 'NCBI530', 'NCBI336', 'MISC2', 'NCBI720', 'MEND66', 'NCBI527', 'SPA8', 'NCBI360', 'NCBI349', 'NCBI379', 'NCBI657', 'NCBI365', 'MEND55', 'TENX131', 'NCBI665', 'NCBI393', 'MEND63', 'NCBI636', 'TENX159', 'NCBI407', 'TENX77', 'MEND76', 'SPA15', 'MEND77', 'NCBI664', 'NCBI369', 'NCBI343', 'SPA12', 'MEND129', 'NCBI666', 'NCBI661', 'NCBI531', 'NCBI352', 'NCBI391', 'NCBI345', 'NCBI667', 'ZEN61', 'TENX43', 'NCBI364', 'MISC3', 'NCBI362', 'MISC6', 'MISC5', 'NCBI397', 'NCBI366', 'NCBI533', 'NCBI409', 'MISC1', 'ZEN60', 'NCBI655', 'NCBI633', 'MEND78', 'MEND124', 'NCBI376', 'TENX60', 'NCBI635', 'NCBI408', 'SPA10', 'NCBI380', 'NCBI363', 'NCBI800', 'NCBI638', 'MEND44', 'NCBI631', 'TENX18', 'MISC12', 'TENX84', 'SPA13', 'NCBI641', 'NCBI662', 'NCBI337', 'NCBI348', 'NCBI715', 'NCBI350', 'NCBI344', 'NCBI398', 'NCBI357', 'MISC10', 'TENX27', 'NCBI371', 'SPA7', 'NCBI660', 'NCBI406', 'NCBI640', 'NCBI353', 'TENX79', 'NCBI400', 'NCBI356', 'MEND74', 'MISC7', 'TENX67', 'TENX80', 'NCBI717', 'NCBI659', 'NCBI629', 'SPA6', 'MEND43', 'NCBI381', 'NCBI718', 'NCBI529', 'NCBI358', 'MEND73', 'MEND68', 'NCBI670', 'NCBI634', 'MEND130', 'NCBI383', 'NCBI653', 'NCBI374', 'NCBI802', 'NCBI654', 'MEND131', 'TENX61', 'NCBI716', 'MEND42', 'NCBI395', 'NCBI341', 'TENX30', 'NCBI532', 'NCBI628', 'NCBI390', 'TENX19', 'NCBI370', 'TENX52', 'NCBI396', 'NCBI528', 'MEND71', 'NCBI340', 'NCBI663', 'TENX87', 'NCBI637', 'NCBI808', 'MISC11', 'NCBI403', 'MEND50', 'MEND64', 'NCBI394', 'NCBI368', 'NCBI671', 'TENX31', 'NCBI359', 'TENX73', 'NCBI347', 'NCBI658', 'NCBI401', 'NCBI355', 'MISC8', 'NCBI806', 'NCBI630', 'SPA14', 'NCBI404', 'NCBI387', 'NCBI668', 'NCBI799', 'NCBI342', 'TENX82', 'NCBI384', 'NCBI351', 'NCBI386', 'NCBI367', 'MISC9', 'NCBI361', 'TENX86', 'NCBI632', 'NCBI354', 'SPA5', 'NCBI405', 'NCBI402', 'NCBI372', 'NCBI346', 'NCBI639', 'MEND46', 'TENX88', 'TENX83', 'NCBI385', 'MEND72', 'TENX56', 'NCBI669', 'NCBI809', 'MEND123'}
# Found 211 potential samples to process.
# Warning: Invalid --num_raw_genes value (-1) provided. Attempting to infer...
# Attempting to determine expected gene count...
# Determined expected gene count: 32285 (from /cwStorage/nodecw_group/jijh/hest_output/MEND123_expr/MEND123_10922_20129.pt)
# Starting parallel processing with 8 jobs...
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND75_expr/MEND75_39132_17888.pt (expected 32285, got 19465). Skipping sample MEND75.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND76_expr/MEND76_37289_22784.pt (expected 32285, got 19465). Skipping sample MEND76.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND77_expr/MEND77_25989_5988.pt (expected 32285, got 19465). Skipping sample MEND77.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND78_expr/MEND78_20479_41707.pt (expected 32285, got 19465). Skipping sample MEND78.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC1_expr/MISC1_6140_8475.pt (expected 32285, got 33538). Skipping sample MISC1.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC10_expr/MISC10_11267_4903.pt (expected 32285, got 33538). Skipping sample MISC10.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC11_expr/MISC11_9889_7575.pt (expected 32285, got 33538). Skipping sample MISC11.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC12_expr/MISC12_8269_6130.pt (expected 32285, got 33538). Skipping sample MISC12.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC2_expr/MISC2_5339_6072.pt (expected 32285, got 33538). Skipping sample MISC2.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC3_expr/MISC3_4780_4436.pt (expected 32285, got 33538). Skipping sample MISC3.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC4_expr/MISC4_9034_5705.pt (expected 32285, got 33538). Skipping sample MISC4.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC5_expr/MISC5_9168_4139.pt (expected 32285, got 33538). Skipping sample MISC5.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC6_expr/MISC6_5632_8208.pt (expected 32285, got 33538). Skipping sample MISC6.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC7_expr/MISC7_4246_7003.pt (expected 32285, got 33538). Skipping sample MISC7.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC8_expr/MISC8_4671_10015.pt (expected 32285, got 33538). Skipping sample MISC8.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MISC9_expr/MISC9_8590_5109.pt (expected 32285, got 33538). Skipping sample MISC9.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI336_expr/NCBI336_5534_7557.pt (expected 32285, got 23371). Skipping sample NCBI336.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI337_expr/NCBI337_5815_4639.pt (expected 32285, got 23371). Skipping sample NCBI337.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI338_expr/NCBI338_6640_7565.pt (expected 32285, got 23371). Skipping sample NCBI338.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI339_expr/NCBI339_6049_2887.pt (expected 32285, got 23371). Skipping sample NCBI339.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI340_expr/NCBI340_5531_1986.pt (expected 32285, got 23371). Skipping sample NCBI340.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI341_expr/NCBI341_6117_3199.pt (expected 32285, got 23371). Skipping sample NCBI341.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI342_expr/NCBI342_3824_554.pt (expected 32285, got 23371). Skipping sample NCBI342.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI343_expr/NCBI343_5564_275.pt (expected 32285, got 23371). Skipping sample NCBI343.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCB

# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND63_expr/MEND63_7922_18291.pt (expected 32285, got 17943). Skipping sample MEND63.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND64_expr/MEND64_15503_22648.pt (expected 32285, got 17943). Skipping sample MEND64.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND65_expr/MEND65_26225_23567.pt (expected 32285, got 17943). Skipping sample MEND65.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND66_expr/MEND66_17079_29706.pt (expected 32285, got 17943). Skipping sample MEND66.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND67_expr/MEND67_24234_15946.pt (expected 32285, got 36601). Skipping sample MEND67.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND68_expr/MEND68_6980_29732.pt (expected 32285, got 36601). Skipping sample MEND68.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND44_expr/MEND44_27576_25887.pt (expected 32285, got 31053). Skipping sample MEND44.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND42_expr/MEND42_23524_20694.pt (expected 32285, got 31053). Skipping sample MEND42.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/MEND131_expr/MEND131_9250_9870.pt (expected 32285, got 31053). Skipping sample MEND131.
#
# Finished processing.
# Successfully processed 41 / 211 targeted samples.
# Total valid spots found: 122423
# Valid spots list saved to /cwStorage/nodecw_group/jijh/hest_graph_data_filtered/valid_spots_flat_filtered.pkl
# Preprocessing complete.
#
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI372_expr/NCBI372_2044_6385.pt (expected 32285, got 23371). Skipping sample NCBI372.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI373_expr/NCBI373_2613_8106.pt (expected 32285, got 23371). Skipping sample NCBI373.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI374_expr/NCBI374_7858_4901.pt (expected 32285, got 23371). Skipping sample NCBI374.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI375_expr/NCBI375_869_6067.pt (expected 32285, got 23371). Skipping sample NCBI375.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI376_expr/NCBI376_6095_1399.pt (expected 32285, got 23371). Skipping sample NCBI376.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI377_expr/NCBI377_6680_8106.pt (expected 32285, got 23371). Skipping sample NCBI377.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI380_expr/NCBI380_4346_2335.pt (expected 32285, got 23371). Skipping sample NCBI380.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI381_expr/NCBI381_2586_2304.pt (expected 32285, got 23371). Skipping sample NCBI381.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI384_expr/NCBI384_3190_4588.pt (expected 32285, got 23371). Skipping sample NCBI384.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI385_expr/NCBI385_4633_5507.pt (expected 32285, got 23371). Skipping sample NCBI385.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI388_expr/NCBI388_4083_1120.pt (expected 32285, got 23371). Skipping sample NCBI388.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI389_expr/NCBI389_6119_8115.pt (expected 32285, got 23371). Skipping sample NCBI389.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI392_expr/NCBI392_4636_2321.pt (expected 32285, got 23371). Skipping sample NCBI392.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI393_expr/NCBI393_4074_3757.pt (expected 32285, got 23371). Skipping sample NCBI393.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI396_expr/NCBI396_4071_4320.pt (expected 32285, got 23371). Skipping sample NCBI396.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI397_expr/NCBI397_6708_1688.pt (expected 32285, got 23371). Skipping sample NCBI397.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI400_expr/NCBI400_4659_8136.pt (expected 32285, got 23371). Skipping sample NCBI400.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI401_expr/NCBI401_4665_3766.pt (expected 32285, got 23371). Skipping sample NCBI401.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI406_expr/NCBI406_4099_6400.pt (expected 32285, got 23371). Skipping sample NCBI406.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI407_expr/NCBI407_7273_2340.pt (expected 32285, got 23371). Skipping sample NCBI407.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI408_expr/NCBI408_5828_6399.pt (expected 32285, got 23371). Skipping sample NCBI408.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCBI409_expr/NCBI409_2317_5770.pt (expected 32285, got 23371). Skipping sample NCBI409.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/NCB

# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX19_expr/TENX19_2977_5357.pt (expected 32285, got 31053). Skipping sample TENX19.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX27_expr/TENX27_5976_8823.pt (expected 32285, got 36601). Skipping sample TENX27.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX30_expr/TENX30_3122_10081.pt (expected 32285, got 1253). Skipping sample TENX30.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX31_expr/TENX31_8155_4566.pt (expected 32285, got 36601). Skipping sample TENX31.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX43_expr/TENX43_10025_14133.pt (expected 32285, got 19465). Skipping sample TENX43.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX52_expr/TENX52_9393_2588.pt (expected 32285, got 31053). Skipping sample TENX52.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX54_expr/TENX54_8142_2015.pt (expected 32285, got 31053). Skipping sample TENX54.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX55_expr/TENX55_9165_6328.pt (expected 32285, got 31053). Skipping sample TENX55.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX56_expr/TENX56_4297_9092.pt (expected 32285, got 1186). Skipping sample TENX56.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX60_expr/TENX60_23927_10527.pt (expected 32285, got 19465). Skipping sample TENX60.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX61_expr/TENX61_9700_14548.pt (expected 32285, got 19465). Skipping sample TENX61.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX69_expr/TENX69_17489_6980.pt (expected 32285, got 19465). Skipping sample TENX69.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX73_expr/TENX73_27736_34445.pt (expected 32285, got 18085). Skipping sample TENX73.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX77_expr/TENX77_21735_22146.pt (expected 32285, got 19465). Skipping sample TENX77.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX78_expr/TENX78_22379_12867.pt (expected 32285, got 19465). Skipping sample TENX78.
# Warning: Gene count mismatch in /cwStorage/nodecw_group/jijh/hest_output/TENX79_expr/TENX79_14869_27931.pt (expected 32285, got 19465). Skipping sample TENX79.
#
# --- Preprocessing Script STDERR ---
#
# Processing Samples:   0%|          | 0/211 [00:00<?, ?it/s]
# Processing Samples:   8%|▊         | 16/211 [00:04<00:53,  3.64it/s]
# Processing Samples:  11%|█▏        | 24/211 [00:04<00:31,  6.00it/s]/public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
#
# Processing Samples:  15%|█▌        | 32/211 [00:17<02:09,  1.38it/s]
# Processing Samples:  19%|█▉        | 40/211 [00:17<01:21,  2.10it/s]/public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
#
# Processing Samples:  27%|██▋       | 56/211 [00:18<00:37,  4.11it/s]
# Processing Samples:  49%|████▉     | 104/211 [00:18<00:08, 12.61it/s]
# Processing Samples: 100%|██████████| 211/211 [00:18<00:00, 11.56it/s]
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
# /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/graph_utils.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   edge_index = torch.tensor([adj_coo.row, adj_coo.col], dtype=torch.long)
#
# Preprocessing script completed successfully.

# %% [markdown]
# ## Cell 5: Optional - Test Dataset Loading

# %%
print("\n--- Testing Dataset Loading (Precomputed) ---")
try:
    test_config = TrainingConfig() # Use current config
    start_time = time.time()
    test_dataset = SpatialGraphDataset(test_config)
    end_time = time.time()
    print(f"Dataset loaded in {end_time - start_time:.2f} seconds.")
    print(f"Number of valid spots: {len(test_dataset)}")
    print(f"Detected node feature dimension: {test_dataset.node_feature_dim}")

    if len(test_dataset) > 0:
        print("\nTesting __getitem__...")
        try:
             from torch_geometric.data import Data
             item = test_dataset[0]
             print("Item retrieved successfully.")
             print("Item type:", type(item))
             if isinstance(item, Data):
                 print("Item keys:", item.keys)
                 print("Node features shape:", item.x.shape)
                 print("Target latent shape:", item.y.shape)
             else: print("Retrieved item is not a PyG Data object.")
        except ImportError: print("PyTorch Geometric not found. Cannot fully test __getitem__ returning Data object.")
        except Exception as e: print(f"Error during __getitem__ test: {e}"); raise e

except Exception as e:
    print(f"Error during dataset test: {e}")
    print("Check paths to precomputed data and valid spots file.")
    raise e
# Out:
# --- Testing Dataset Loading (Precomputed) ---
# Loading valid spots list from: /cwStorage/nodecw_group/jijh/hest_graph_data_filtered/valid_spots_flat_filtered.pkl
# Loaded 122423 valid spot entries.
# Found 41 precomputed graph files.
# Detected node feature dimension from graphs: 178
# Dataset loaded in 0.05 seconds.
# Number of valid spots: 122423
# Detected node feature dimension: 178
#
# Testing __getitem__...
# ERROR: Failed loading latent file /cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123/MEND123_28618_24487.pt for idx 0: [Errno 2] No such file or directory: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123/MEND123_28618_24487.pt'
# Error during __getitem__ test: [Errno 2] No such file or directory: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123/MEND123_28618_24487.pt'
# Error during dataset test: [Errno 2] No such file or directory: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123/MEND123_28618_24487.pt'
# Check paths to precomputed data and valid spots file.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 29
#      27 print(f"Error during dataset test: {e}")
#      28 print("Check paths to precomputed data and valid spots file.")
# ---> 29 raise e
#
# Cell In[34], line 24
#      22              else: print("Retrieved item is not a PyG Data object.")
#      23         except ImportError: print("PyTorch Geometric not found. Cannot fully test __getitem__ returning Data object.")
# ---> 24         except Exception as e: print(f"Error during __getitem__ test: {e}"); raise e
#      26 except Exception as e:
#      27     print(f"Error during dataset test: {e}")
#
# Cell In[34], line 15
#      13 try:
#      14      from torch_geometric.data import Data
# ---> 15      item = test_dataset[0]
#      16      print("Item retrieved successfully.")
#      17      print("Item type:", type(item))
#
# File /public/home/jijh/diffusion_project/ADiffusion/graph_transformer_trial/dataset.py:92, in __getitem__(self, idx)
#      90 def __getitem__(self, idx):
#      91     if idx >= len(self.valid_spots_flat):
# ---> 92          raise IndexError("Index out of range")
#      94     sampleid, x, y = self.valid_spots_flat[idx]
#      96     # Load the precomputed graph data
#
# File /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/serialization.py:1319, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1316 if "encoding" not in pickle_load_args.keys():
#    1317     pickle_load_args["encoding"] = "utf-8"
# -> 1319 with _open_file_like(f, "rb") as opened_file:
#    1320     if _is_zipfile(opened_file):
#    1321         # The zipfile reader is going to advance the current file position.
#    1322         # If we want to actually tail call to torch.jit.load, we need to
#    1323         # reset back to the original position.
#    1324         orig_position = opened_file.tell()
#
# File /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/serialization.py:659, in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# File /public/home/jijh/micromamba/envs/gpu_env/lib/python3.12/site-packages/torch/serialization.py:640, in _open_file.__init__(self, name, mode)
#     639 def __init__(self, name, mode):
# --> 640     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/cwStorage/nodecw_group/jijh/hest_output_latents_bf16/MEND123/MEND123_28618_24487.pt'

# %% [markdown]
# ## Cell 6: Optional - Test Model Instantiation

# %%
print("\n--- Testing Model Instantiation ---")
try:
    model_config = TrainingConfig()
    # Add detected dimension to config obj passed to model, in case it's needed
    # setattr(model_config, 'graph_input_dim', test_dataset.node_feature_dim)
    test_model = FullModel(model_config)
    print("FullModel initialized.")

    if model_config.pretrained_unet_checkpoint_path and os.path.exists(model_config.pretrained_unet_checkpoint_path):
        print(f"Loading UNet weights from: {model_config.pretrained_unet_checkpoint_path}")
        test_model.load_unet_weights(model_config.pretrained_unet_checkpoint_path)
    else: print("Pretrained UNet path not specified or not found.")

    total_params = sum(p.numel() for p in test_model.parameters())
    trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
    print(f"Total parameters: {total_params:,}")
    print(f"Trainable parameters: {trainable_params:,}")

except ImportError as e: print(f"Import Error during model test (likely PyG layers): {e}")
except Exception as e: print(f"Error during model test: {e}"); raise e
