# %%
import base64

# %%
def decode_configurations(config_string: str):
    """
    Given a multiline string with configurations (e.g., vmess:// or ss://),
    split it by newline and decode the base64 part.
    
    For vmess:// URLs, the whole part after "://" is assumed to be base64.
    For ss:// URLs, the base64 encoded part is taken from the beginning up to the first "@".
    
    Parameters:
        config_string (str): The input string containing configuration lines.
        
    Returns:
        list of str: A list with each decoded configuration (or an error message if decoding fails).
    """
    decoded_results = []
    
    # Split the string into lines
    lines = config_string.splitlines()
    
    for line in lines:
        line = line.strip()
        # Skip empty lines
        if not line:
            continue
        
        # Check for a scheme (e.g., vmess:// or ss://)
        if "://" not in line:
            decoded_results.append(f"Line skipped (no scheme): {line}")
            continue
        
        scheme, rest = line.split("://", 1)
        b64_part = ""
        
        if scheme.lower() == "vmess":
            # For vmess, assume that the whole part after '://' is base64.
            b64_part = rest
        elif scheme.lower() == "ss":
            # For ss, the base64 encoded part is usually before the '@'
            if "@" in rest:
                b64_part = rest.split("@", 1)[0]
            else:
                b64_part = rest
        else:
            # If it's not a scheme we intend to decode, simply note it.
            decoded_results.append(f"Not handling scheme '{scheme}': {line}")
            continue
        
        # Fix padding if necessary (base64 strings should have a length that is a multiple of 4)
        missing_padding = len(b64_part) % 4
        if missing_padding:
            b64_part += '=' * (4 - missing_padding)
        
        try:
            # Decode the base64 string and decode bytes to utf-8 string
            decoded = base64.b64decode(b64_part).decode('utf-8')
        except Exception as e:
            decoded = f"Error decoding base64: {e}"
        
        decoded_results.append(decoded)
    
    return decoded_results

# %%
# Read the txt file as a string
with open("/Users/jay/Downloads/sync_bypy.txt", "r") as f:
    config_string = f.read()

# %%
decode_configurations(config_string)
# Out:
# ['{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[NF]\\u79fb\\u52a8sf\\u2192HK","add":"cm1.qq.com.qqcdnxb.com","port":"18000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[\\u63a8\\u8350]\\u79fb\\u52a84\\u2192\\u9999\\u6e2fhkt","add":"cm4.qq.com.qqcdnxb.com","port":"18000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[NF]\\u79fb\\u52a8hf\\u2192HK","add":"cm2.douyin.com.gbnodex.com","port":"18000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[NF]\\u79fb\\u52a8gf\\u2192\\u9999\\u6e2faz","add":"cc3.douyin.com.gbnodex.com","port":"18000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf0\\ud83c\\uddf7[NF][TikTok]\\u79fb\\u52a8\\u2192\\u97e9\\u56fd4","add":"cm2.douyin.com.gbnodex.com","port":"19117","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf0\\ud83c\\uddf7[NF][TikTok]\\u79fb\\u52a84\\u2192\\u97e9\\u56fd4","add":"cm4.qq.com.qqcdnxb.com","port":"19127","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddef\\ud83c\\uddf5\\u79fb\\u52a83->\\u65e5\\u672c","add":"cc3.douyin.com.gbnodex.com","port":"18019","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[NF]\\u79fb\\u52a83\\u2192\\u9999\\u6e2faz","add":"cc3.douyin.com.gbnodex.com","port":"18001","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddef\\ud83c\\uddf5[DMM][GPT]\\u79fb\\u52a81\\u2192\\u65e5\\u672cg","add":"cm1.qq.com.qqcdnxb.com","port":"31187","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddef\\ud83c\\uddf5[DMM][GPT]\\u79fb\\u52a82\\u2192\\u65e5\\u672cg","add":"cm2.douyin.com.gbnodex.com","port":"31187","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\uddfc[\\u63a8\\u8350]\\u79fb\\u52a84\\u2192\\u53f0\\u6e7e3","add":"cm4.qq.com.qqcdnxb.com","port":"17000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\uddfc[E\\u7ad9][NF]\\u79fb\\u52a82\\u2192\\u53f0\\u6e7e4","add":"cm2.douyin.com.gbnodex.com","port":"17000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\uddfc[E\\u7ad9][NF]\\u79fb\\u52a8\\u2192\\u53f0\\u6e7e3","add":"cm1.qq.com.qqcdnxb.com","port":"17000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\uddfc[NF][ChatGPT]\\u79fb\\u52a83\\u2192\\u53f0\\u6e7e3","add":"cc3.douyin.com.gbnodex.com","port":"17000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddfa\\ud83c\\uddf8\\u79fb\\u52a8\\u2192\\u7f8e\\u56fdo","add":"cm1.qq.com.qqcdnxb.com","port":"19079","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddfa\\ud83c\\uddf8[\\u63a8\\u8350]\\u79fb\\u52a84\\u2192\\u7f8e\\u56fdo","add":"cm4.qq.com.qqcdnxb.com","port":"19179","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddfa\\ud83c\\uddf8\\u79fb\\u52a82\\u2192\\u7f8e\\u56fdsea","add":"cm2.douyin.com.gbnodex.com","port":"19079","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddfa\\ud83c\\uddf8\\u79fb\\u52a83\\u2192\\u7f8e\\u56fdo","add":"cc3.douyin.com.gbnodex.com","port":"19079","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf8\\ud83c\\uddec[ChatGPT]\\u79fb\\u52a83\\u2192\\u65b0\\u52a0\\u5761c","add":"cc3.douyin.com.gbnodex.com","port":"19011","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf8\\ud83c\\uddec[Netflix]\\u79fb\\u52a8s\\u2192\\u65b0\\u52a0\\u5761","add":"cm1.qq.com.qqcdnxb.com","port":"19011","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf8\\ud83c\\uddec[Netflix]\\u79fb\\u52a82\\u2192\\u65b0\\u52a0\\u5761","add":"cm2.douyin.com.gbnodex.com","port":"19011","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf7\\ud83c\\uddfa[BT][YouTube\\u65e0\\u5e7f\\u544a]\\u4fc4\\u7f57\\u65af","add":"cm1.qq.com.qqcdnxb.com","port":"17201","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf7\\ud83c\\uddfa[BT][YouTube\\u65e0\\u5e7f\\u544a]\\u4fc4\\u7f57\\u65af2","add":"cc3.douyin.com.gbnodex.com","port":"17201","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf7\\ud83c\\uddfa[BT][YouTube\\u65e0\\u5e7f\\u544a]\\u4fc4\\u7f57\\u65af3","add":"cm2.douyin.com.gbnodex.com","port":"17201","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\udde9\\ud83c\\uddea\\u79fb\\u52a81\\u2192\\u5fb7\\u56fd","add":"cm1.qq.com.qqcdnxb.com","port":"51793","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\udde9\\ud83c\\uddea\\u79fb\\u52a8\\u2192\\u5fb7\\u56fd","add":"cm2.douyin.com.gbnodex.com","port":"51792","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@twhi3.geeknetwork.fun:21077?insecure=1#%F0%9F%87%B9%F0%9F%87%BC%5BHY%5D%5BChatGPT%5D%E7%9B%B4%E8%BF%9E-%3E%E5%8F%B0%E6%B9%BE3",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@twhi4.geeknetwork.fun:21077?insecure=1#%F0%9F%87%B9%F0%9F%87%BC%5BHY%5D%5BChatGPT%5D%E7%9B%B4%E8%BF%9E-%3E%E5%8F%B0%E6%B9%BE4",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@kr4.geeknetwork.fun:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%B0%F0%9F%87%B7%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E9%9F%A9%E5%9B%BD4",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@160.16.237.241:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC3",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@160.16.53.111:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC4",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@hkt1.geeknetwork.fun:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AD%F0%9F%87%B0%5BHY%5D%E7%9B%B4%E8%BF%9E-%3E%E9%A6%99%E6%B8%AFhkt",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@160.16.114.236:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@160.16.200.209:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC2",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@153.121.72.155:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC8",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@160.16.205.217:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC7",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@160.16.134.79:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC5",
#  "Not handling scheme 'hysteria2': hysteria2://77f3f4a6-ba9b-41ab-be40-481b2746f8be@160.16.107.214:21077?sni=bestcast.pw&security=tls&insecure=1#%F0%9F%87%AF%F0%9F%87%B5%5BHY%5D%5BTikTok%5D%E7%9B%B4%E8%BF%9E-%3E%E6%97%A5%E6%9C%AC6",
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\udded[TikTok][NF]\\u79fb\\u52a8\\u2192\\u6cf0\\u56fd","add":"cm1.qq.com.qqcdnxb.com","port":"19817","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\udded[TikTok][NF]\\u79fb\\u52a82\\u2192\\u6cf0\\u56fd","add":"cm2.douyin.com.gbnodex.com","port":"19817","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddfb\\ud83c\\uddf3[TikTok][NF]\\u79fb\\u52a8\\u2192\\u8d8a\\u5357","add":"cm1.qq.com.qqcdnxb.com","port":"17097","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddfb\\ud83c\\uddf3[TikTok][NF]\\u79fb\\u52a82\\u2192\\u8d8a\\u5357","add":"cm2.douyin.com.gbnodex.com","port":"17097","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf2\\ud83c\\uddfe[TikTok][NF]\\u79fb\\u52a8\\u2192\\u9a6c\\u6765\\u897f\\u4e9a","add":"cm1.qq.com.qqcdnxb.com","port":"17057","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf2\\ud83c\\uddfe[TikTok][NF]\\u79fb\\u52a82\\u2192\\u9a6c\\u6765\\u897f\\u4e9a","add":"cm2.douyin.com.gbnodex.com","port":"17057","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddee\\ud83c\\udde9[NF][Tiktok]\\u79fb\\u52a81->\\u5370\\u5c3c","add":"cm1.qq.com.qqcdnxb.com","port":"17017","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddee\\ud83c\\udde9[NF][Tiktok]\\u79fb\\u52a82->\\u5370\\u5c3c","add":"cm2.douyin.com.gbnodex.com","port":"17017","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf5\\ud83c\\udded[Tiktok]\\u79fb\\u52a8->\\u83f2\\u5f8b\\u5bbe","add":"cm1.qq.com.qqcdnxb.com","port":"17013","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf5\\ud83c\\udded[Tiktok]\\u79fb\\u52a82->\\u83f2\\u5f8b\\u5bbe","add":"cm2.douyin.com.gbnodex.com","port":"17013","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '{"v":"2","ps":"\\ud83c\\uddec\\ud83c\\udde7\\u79fb\\u52a8->\\u82f1\\u56fd","add":"cm1.qq.com.qqcdnxb.com","port":"19112","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddec\\ud83c\\udde7\\u79fb\\u52a83->\\u82f1\\u56fd","add":"cc3.douyin.com.gbnodex.com","port":"19112","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\uddf7[Steam\\u5546\\u5e97][ChatGPT]\\u2192\\u571f\\u8033\\u5176","add":"cm1.qq.com.qqcdnxb.com","port":"17203","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddf9\\ud83c\\uddf7[Steam\\u5546\\u5e97][ChatGPT]\\u2192\\u571f\\u8033\\u51762","add":"cm2.douyin.com.gbnodex.com","port":"17203","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddef\\ud83c\\uddf5[\\u5907\\u75283][\\u57df\\u540d\\u65e0\\u6cd5\\u89e3\\u6790\\u65f6\\u7528]","add":"120.233.87.131","port":"18019","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[\\u5907\\u75285][\\u57df\\u540d\\u65e0\\u6cd5\\u89e3\\u6790\\u65f6\\u7528]","add":"120.241.224.10","port":"18000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[\\u5907\\u75286][\\u63a8\\u8350]","add":"120.237.215.29","port":"18000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '{"v":"2","ps":"\\ud83c\\uddef\\ud83c\\uddf5[\\u5907\\u75284][\\u57df\\u540d\\u65e0\\u6cd5\\u89e3\\u6790\\u65f6\\u7528]","add":"36.156.184.11","port":"31187","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '2022-blake3-aes-128-gcm:OGFhNDc2N2FmOGI5ZTE4MA==:NzdmM2Y0YTYtYmE5Yi00MQ==',
#  '{"v":"2","ps":"\\ud83c\\udded\\ud83c\\uddf0[\\u2661\\u8bf7\\u5e38\\u66f4\\u65b0\\u8ba2\\u9605\\u2194\\u597d\\u4e60\\u60ef]","add":"36.156.184.11","port":"18000","id":"77f3f4a6-ba9b-41ab-be40-481b2746f8be","aid":"0","net":"tcp","type":"none","host":"","path":"","tls":""}']
